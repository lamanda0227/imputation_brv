# %% [markdown]
# # PCSK9 vs. APOC3
#
# This notebook records [BRV](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4459641/) analysis result for PCSK9 v.s LDL and APOC3 v.s. TG

# %% [markdown]
# ## Extract PCSK9 + APOC3

# %%
library(dplyr)
library(data.table)
setwd("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last

# %% [markdown]
# ### Exome

# %%
for(chr in c(1,11)){
    gene <- ifelse(chr==1, "PCSK9", "APOC3")
    
    for(maf in c(0.01, 0.005, 0.001)){
        maf_c <- gsub("\\.", "", as.character(maf))
        
        annot <- read.csv(sprintf("./exome/ukb23156_c%i.merged.filtered.hg38.hg38_multianno_formatted_sel_col_maf%s_LOF_missense.csv.gz", chr, maf_c)) %>% 
            filter(Gene.refGene == gene)
        annot %>% fwrite(sprintf("./%s/%s_exome_maf%s_annot.csv.gz", tolower(gene), gene, maf_c))
        annot %>% select(ID_hg38) %>% fwrite(sprintf("./%s/%s_exome_maf%s_extractlist_snplist", tolower(gene), gene, maf_c), col.names = FALSE)
        
        annot_cadd <- read.csv(sprintf("./exome/ukb23156_c%i.merged.filtered.hg38.hg38_multianno_formatted_sel_col_maf%s_LOF_missense_cadd.csv.gz", chr, maf_c)) %>% 
            filter(Gene.refGene == gene)
        annot_cadd %>% fwrite(sprintf("./%s/%s_exome_maf%s_cadd_annot.csv.gz", tolower(gene), gene, maf_c))
        annot_cadd %>% select(ID_hg38) %>% fwrite(sprintf("./%s/%s_exome_maf%s_cadd_extractlist_snplist", tolower(gene), gene, maf_c), col.names = FALSE)
    }
}

# %% [markdown]
# ### HRC

# %%
for(chr in c(1,11)){
    gene <- ifelse(chr==1, "PCSK9", "APOC3")
    
    for(rsq in c(3, 8)){
        for(maf in c(0.01, 0.005, 0.001)){
            maf_c <- gsub("\\.", "", as.character(maf))

            annot <- read.csv(sprintf("./hrc/hrc_chr%i_rsq0%i_hg19_hg38_maf%s_LOF_missense_annot.csv.gz", chr, rsq, maf_c)) %>% 
                filter(Gene.refGene == gene)
            annot %>% fwrite(sprintf("./%s/%s_hrc_rsq0%i_maf%s_annot.csv.gz", tolower(gene), gene, rsq, maf_c))
            annot %>% select(ID_hg19) %>% fwrite(sprintf("./%s/%s_hrc_rsq0%i_maf%s_extractlist_snplist", tolower(gene), gene, rsq, maf_c), col.names = FALSE)
        }
    }
}

# %%
for(chr in c(1, 11)){
    gene <- ifelse(chr==1, "PCSK9", "APOC3")
    
    for(rsq in c(3, 8)){
        for(maf in c(0.01, 0.005, 0.001)){
            maf_c <- gsub("\\.", "", as.character(maf))

            annot_cadd <- read.csv(sprintf("./hrc/hrc_chr%i_rsq0%i_hg19_hg38_maf%s_LOF_missense_cadd_annot.csv.gz", chr, rsq, maf_c)) %>% 
                filter(Gene.refGene == gene)
            annot_cadd %>% fwrite(sprintf("./%s/%s_hrc_rsq0%i_maf%s_cadd_annot.csv.gz", tolower(gene), gene, rsq, maf_c))
            annot_cadd %>% select(ID_hg19) %>% fwrite(sprintf("./%s/%s_hrc_rsq0%i_maf%s_cadd_extractlist_snplist", tolower(gene), gene, rsq, maf_c), col.names = FALSE)
        }
    }
}

# %% [markdown]
# ### TOPMed

# %%
for(chr in c(1, 11)){
    gene <- ifelse(chr==1, "PCSK9", "APOC3")
    
    for(rsq in c(3, 8)){
        for(maf in c(0.01, 0.005, 0.001)){
            maf_c <- gsub("\\.", "", as.character(maf))

            annot <- read.csv(sprintf("./topmed_v3/topmed_chr%i_rsq0%i_hg38_hg38_maf%s_LOF_missense_annot.csv.gz", chr, rsq, maf_c)) %>% 
                filter(Gene.refGene == gene)
            annot %>% fwrite(sprintf("./%s/%s_topmed_v3_rsq0%i_maf%s_annot.csv.gz", tolower(gene), gene, rsq, maf_c))
            annot %>% select(ID_hg38) %>% fwrite(sprintf("./%s/%s_topmed_v3_rsq0%i_maf%s_extractlist_snplist", tolower(gene), gene, rsq, maf_c), col.names = FALSE)
        }
    }
}

# %%
for(chr in c(1, 11)){
    gene <- ifelse(chr==1, "PCSK9", "APOC3")
    for(rsq in c(3, 8)){
        for(maf in c(0.01, 0.005, 0.001)){
            maf_c <- gsub("\\.", "", as.character(maf))

            annot_cadd <- read.csv(sprintf("./topmed_v3/topmed_chr%i_rsq0%i_hg38_hg38_maf%s_LOF_missense_cadd_annot.csv.gz", chr, rsq, maf_c)) %>% 
                filter(Gene.refGene == gene)
            annot_cadd %>% fwrite(sprintf("./%s/%s_topmed_v3_rsq0%i_maf%s_cadd_annot.csv.gz", tolower(gene), gene, rsq, maf_c))
            annot_cadd %>% select(ID_hg38) %>% fwrite(sprintf("./%s/%s_topmed_v3_rsq0%i_maf%s_cadd_extractlist_snplist", tolower(gene), gene, rsq, maf_c), col.names = FALSE)
        }
    }
}

# %% [markdown]
# ### Extract

# %%
cd ~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/pcsk9

module load Plink/2.00a

for i in 1 05 01; do
    plink2 \
        --bfile ../exome/ukb23156_c1_maf00${i}_LOF_missense_extracted \
        --extract PCSK9_exome_maf00${i}_extractlist_snplist \
        --make-bed --export A \
        --out PCSK9_exome_maf00${i}_extracted

    for j in 3 8; do
        plink2 \
            --bpfile ../hrc/hrc_chr1_rsq0${j}_maf00${i}_LOF_missense_extracted \
            --extract PCSK9_hrc_rsq0${j}_maf00${i}_extractlist_snplist \
            --make-bpgen --sort-vars \
            --export A \
            --out PCSK9_hrc_rsq0${j}_maf00${i}_extracted

        plink2 \
            --bpfile ../topmed_v3/topmed_chr1_rsq0${j}_maf00${i}_LOF_missense_extracted \
            --extract PCSK9_topmed_v3_rsq0${j}_maf00${i}_extractlist_snplist \
            --make-bpgen --sort-vars \
            --export A \
            --out PCSK9_topmed_v3_rsq0${j}_maf00${i}_extracted
    done
done
# Out:
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_exome_maf001_extracted.log.
# Options in effect:
#   --bfile ../exome/ukb23156_c1_maf001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_exome_maf001_extractlist_snplist
#   --make-bed
#   --out PCSK9_exome_maf001_extracted
#
# Start time: Fri Jul  5 13:50:10 2024
# 515666 MiB RAM detected, ~490443 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../exome/ukb23156_c1_maf001_LOF_missense_extracted.fam.
# 478357 variants loaded from
# ../exome/ukb23156_c1_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 394 variants remaining.
# 394 variants remaining after main filters.
# Writing PCSK9_exome_maf001_extracted.fam ... done.
# Writing PCSK9_exome_maf001_extracted.bim ... done.
# Writing PCSK9_exome_maf001_extracted.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_exome_maf001_extracted.raw written.
# End time: Fri Jul  5 13:50:20 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_hrc_rsq03_maf001_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr1_rsq03_maf001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_hrc_rsq03_maf001_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_hrc_rsq03_maf001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:50:20 2024
# 515666 MiB RAM detected, ~490429 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr1_rsq03_maf001_LOF_missense_extracted.fam.
# 20551 variants loaded from
# ../hrc/hrc_chr1_rsq03_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 16 variants remaining.
# 16 variants remaining after main filters.
# Writing PCSK9_hrc_rsq03_maf001_extracted.bim ... done.
# Writing PCSK9_hrc_rsq03_maf001_extracted.fam ... done.
# Writing PCSK9_hrc_rsq03_maf001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_hrc_rsq03_maf001_extracted.raw written.
# End time: Fri Jul  5 13:50:22 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_topmed_v3_rsq03_maf001_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr1_rsq03_maf001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_topmed_v3_rsq03_maf001_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_topmed_v3_rsq03_maf001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:50:22 2024
# 515666 MiB RAM detected, ~490420 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr1_rsq03_maf001_LOF_missense_extracted.fam.
# 141967 variants loaded from
# ../topmed_v3/topmed_chr1_rsq03_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 124 variants remaining.
# 124 variants remaining after main filters.
# Writing PCSK9_topmed_v3_rsq03_maf001_extracted.bim ... done.
# Writing PCSK9_topmed_v3_rsq03_maf001_extracted.fam ... done.
# Writing PCSK9_topmed_v3_rsq03_maf001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_topmed_v3_rsq03_maf001_extracted.raw written.
# End time: Fri Jul  5 13:50:22 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_hrc_rsq08_maf001_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr1_rsq08_maf001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_hrc_rsq08_maf001_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_hrc_rsq08_maf001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:50:22 2024
# 515666 MiB RAM detected, ~490416 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr1_rsq08_maf001_LOF_missense_extracted.fam.
# 8396 variants loaded from
# ../hrc/hrc_chr1_rsq08_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 6 variants remaining.
# 6 variants remaining after main filters.
# Writing PCSK9_hrc_rsq08_maf001_extracted.bim ... done.
# Writing PCSK9_hrc_rsq08_maf001_extracted.fam ... done.
# Writing PCSK9_hrc_rsq08_maf001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_hrc_rsq08_maf001_extracted.raw written.
# End time: Fri Jul  5 13:50:23 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_topmed_v3_rsq08_maf001_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr1_rsq08_maf001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_topmed_v3_rsq08_maf001_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_topmed_v3_rsq08_maf001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:50:23 2024
# 515666 MiB RAM detected, ~490411 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr1_rsq08_maf001_LOF_missense_extracted.fam.
# 45669 variants loaded from
# ../topmed_v3/topmed_chr1_rsq08_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 34 variants remaining.
# 34 variants remaining after main filters.
# Writing PCSK9_topmed_v3_rsq08_maf001_extracted.bim ... done.
# Writing PCSK9_topmed_v3_rsq08_maf001_extracted.fam ... done.
# Writing PCSK9_topmed_v3_rsq08_maf001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_topmed_v3_rsq08_maf001_extracted.raw written.
# End time: Fri Jul  5 13:50:25 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_exome_maf0005_extracted.log.
# Options in effect:
#   --bfile ../exome/ukb23156_c1_maf0005_LOF_missense_extracted
#   --export A
#   --extract PCSK9_exome_maf0005_extractlist_snplist
#   --make-bed
#   --out PCSK9_exome_maf0005_extracted
#
# Start time: Fri Jul  5 13:50:25 2024
# 515666 MiB RAM detected, ~490402 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../exome/ukb23156_c1_maf0005_LOF_missense_extracted.fam.
# 477452 variants loaded from
# ../exome/ukb23156_c1_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 394 variants remaining.
# 394 variants remaining after main filters.
# Writing PCSK9_exome_maf0005_extracted.fam ... done.
# Writing PCSK9_exome_maf0005_extracted.bim ... done.
# Writing PCSK9_exome_maf0005_extracted.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_exome_maf0005_extracted.raw written.
# End time: Fri Jul  5 13:50:35 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_hrc_rsq03_maf0005_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr1_rsq03_maf0005_LOF_missense_extracted
#   --export A
#   --extract PCSK9_hrc_rsq03_maf0005_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_hrc_rsq03_maf0005_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:50:35 2024
# 515666 MiB RAM detected, ~490351 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr1_rsq03_maf0005_LOF_missense_extracted.fam.
# 19743 variants loaded from
# ../hrc/hrc_chr1_rsq03_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 16 variants remaining.
# 16 variants remaining after main filters.
# Writing PCSK9_hrc_rsq03_maf0005_extracted.bim ... done.
# Writing PCSK9_hrc_rsq03_maf0005_extracted.fam ... done.
# Writing PCSK9_hrc_rsq03_maf0005_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_hrc_rsq03_maf0005_extracted.raw written.
# End time: Fri Jul  5 13:50:37 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_topmed_v3_rsq03_maf0005_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr1_rsq03_maf0005_LOF_missense_extracted
#   --export A
#   --extract PCSK9_topmed_v3_rsq03_maf0005_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_topmed_v3_rsq03_maf0005_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:50:37 2024
# 515666 MiB RAM detected, ~490345 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr1_rsq03_maf0005_LOF_missense_extracted.fam.
# 141141 variants loaded from
# ../topmed_v3/topmed_chr1_rsq03_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 124 variants remaining.
# 124 variants remaining after main filters.
# Writing PCSK9_topmed_v3_rsq03_maf0005_extracted.bim ... done.
# Writing PCSK9_topmed_v3_rsq03_maf0005_extracted.fam ... done.
# Writing PCSK9_topmed_v3_rsq03_maf0005_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_topmed_v3_rsq03_maf0005_extracted.raw written.
# End time: Fri Jul  5 13:50:39 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_hrc_rsq08_maf0005_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr1_rsq08_maf0005_LOF_missense_extracted
#   --export A
#   --extract PCSK9_hrc_rsq08_maf0005_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_hrc_rsq08_maf0005_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:50:40 2024
# 515666 MiB RAM detected, ~490333 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr1_rsq08_maf0005_LOF_missense_extracted.fam.
# 7666 variants loaded from
# ../hrc/hrc_chr1_rsq08_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 6 variants remaining.
# 6 variants remaining after main filters.
# Writing PCSK9_hrc_rsq08_maf0005_extracted.bim ... done.
# Writing PCSK9_hrc_rsq08_maf0005_extracted.fam ... done.
# Writing PCSK9_hrc_rsq08_maf0005_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_hrc_rsq08_maf0005_extracted.raw written.
# End time: Fri Jul  5 13:50:41 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_topmed_v3_rsq08_maf0005_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr1_rsq08_maf0005_LOF_missense_extracted
#   --export A
#   --extract PCSK9_topmed_v3_rsq08_maf0005_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_topmed_v3_rsq08_maf0005_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:50:41 2024
# 515666 MiB RAM detected, ~490326 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr1_rsq08_maf0005_LOF_missense_extracted.fam.
# 44886 variants loaded from
# ../topmed_v3/topmed_chr1_rsq08_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 34 variants remaining.
# 34 variants remaining after main filters.
# Writing PCSK9_topmed_v3_rsq08_maf0005_extracted.bim ... done.
# Writing PCSK9_topmed_v3_rsq08_maf0005_extracted.fam ... done.
# Writing PCSK9_topmed_v3_rsq08_maf0005_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_topmed_v3_rsq08_maf0005_extracted.raw written.
# End time: Fri Jul  5 13:50:43 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_exome_maf0001_extracted.log.
# Options in effect:
#   --bfile ../exome/ukb23156_c1_maf0001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_exome_maf0001_extractlist_snplist
#   --make-bed
#   --out PCSK9_exome_maf0001_extracted
#
# Start time: Fri Jul  5 13:50:43 2024
# 515666 MiB RAM detected, ~490319 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../exome/ukb23156_c1_maf0001_LOF_missense_extracted.fam.
# 473986 variants loaded from
# ../exome/ukb23156_c1_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 393 variants remaining.
# 393 variants remaining after main filters.
# Writing PCSK9_exome_maf0001_extracted.fam ... done.
# Writing PCSK9_exome_maf0001_extracted.bim ... done.
# Writing PCSK9_exome_maf0001_extracted.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_exome_maf0001_extracted.raw written.
# End time: Fri Jul  5 13:50:52 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_hrc_rsq03_maf0001_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr1_rsq03_maf0001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_hrc_rsq03_maf0001_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_hrc_rsq03_maf0001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:50:52 2024
# 515666 MiB RAM detected, ~490399 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr1_rsq03_maf0001_LOF_missense_extracted.fam.
# 16591 variants loaded from
# ../hrc/hrc_chr1_rsq03_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 15 variants remaining.
# 15 variants remaining after main filters.
# Writing PCSK9_hrc_rsq03_maf0001_extracted.bim ... done.
# Writing PCSK9_hrc_rsq03_maf0001_extracted.fam ... done.
# Writing PCSK9_hrc_rsq03_maf0001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_hrc_rsq03_maf0001_extracted.raw written.
# End time: Fri Jul  5 13:50:53 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_topmed_v3_rsq03_maf0001_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr1_rsq03_maf0001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_topmed_v3_rsq03_maf0001_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_topmed_v3_rsq03_maf0001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:50:53 2024
# 515666 MiB RAM detected, ~490392 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr1_rsq03_maf0001_LOF_missense_extracted.fam.
# 137927 variants loaded from
# ../topmed_v3/topmed_chr1_rsq03_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 123 variants remaining.
# 123 variants remaining after main filters.
# Writing PCSK9_topmed_v3_rsq03_maf0001_extracted.bim ... done.
# Writing PCSK9_topmed_v3_rsq03_maf0001_extracted.fam ... done.
# Writing PCSK9_topmed_v3_rsq03_maf0001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_topmed_v3_rsq03_maf0001_extracted.raw written.
# End time: Fri Jul  5 13:50:56 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_hrc_rsq08_maf0001_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr1_rsq08_maf0001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_hrc_rsq08_maf0001_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_hrc_rsq08_maf0001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:50:56 2024
# 515666 MiB RAM detected, ~490377 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr1_rsq08_maf0001_LOF_missense_extracted.fam.
# 5243 variants loaded from
# ../hrc/hrc_chr1_rsq08_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 6 variants remaining.
# 6 variants remaining after main filters.
# Writing PCSK9_hrc_rsq08_maf0001_extracted.bim ... done.
# Writing PCSK9_hrc_rsq08_maf0001_extracted.fam ... done.
# Writing PCSK9_hrc_rsq08_maf0001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_hrc_rsq08_maf0001_extracted.raw written.
# End time: Fri Jul  5 13:50:58 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_topmed_v3_rsq08_maf0001_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr1_rsq08_maf0001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_topmed_v3_rsq08_maf0001_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_topmed_v3_rsq08_maf0001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:50:58 2024
# 515666 MiB RAM detected, ~490369 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr1_rsq08_maf0001_LOF_missense_extracted.fam.
# 42131 variants loaded from
# ../topmed_v3/topmed_chr1_rsq08_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 33 variants remaining.
# 33 variants remaining after main filters.
# Writing PCSK9_topmed_v3_rsq08_maf0001_extracted.bim ... done.
# Writing PCSK9_topmed_v3_rsq08_maf0001_extracted.fam ... done.
# Writing PCSK9_topmed_v3_rsq08_maf0001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_topmed_v3_rsq08_maf0001_extracted.raw written.
# End time: Fri Jul  5 13:50:59 2024

# %%
for i in 1 05 01; do
    plink2 \
        --bfile ../exome/ukb23156_c1_maf00${i}_LOF_missense_extracted \
        --extract PCSK9_exome_maf00${i}_cadd_extractlist_snplist \
        --make-bed --export A \
        --out PCSK9_exome_maf00${i}_cadd_extracted

    for j in 3 8; do
        plink2 \
            --bpfile ../hrc/hrc_chr1_rsq0${j}_maf00${i}_LOF_missense_extracted \
            --extract PCSK9_hrc_rsq0${j}_maf00${i}_cadd_extractlist_snplist \
            --make-bpgen --sort-vars \
            --export A \
            --out PCSK9_hrc_rsq0${j}_maf00${i}_cadd_extracted

        plink2 \
            --bpfile ../topmed_v3/../topmed_v3/topmed_chr1_rsq0${j}_maf00${i}_LOF_missense_extracted \
            --extract PCSK9_topmed_v3_rsq0${j}_maf00${i}_cadd_extractlist_snplist \
            --make-bpgen --sort-vars \
            --export A \
            --out PCSK9_topmed_v3_rsq0${j}_maf00${i}_cadd_extracted
    done
done
# Out:
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_exome_maf001_cadd_extracted.log.
# Options in effect:
#   --bfile ../exome/ukb23156_c1_maf001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_exome_maf001_cadd_extractlist_snplist
#   --make-bed
#   --out PCSK9_exome_maf001_cadd_extracted
#
# Start time: Fri Jul  5 13:52:41 2024
# 515666 MiB RAM detected, ~490275 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../exome/ukb23156_c1_maf001_LOF_missense_extracted.fam.
# 478357 variants loaded from
# ../exome/ukb23156_c1_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 200 variants remaining.
# 200 variants remaining after main filters.
# Writing PCSK9_exome_maf001_cadd_extracted.fam ... done.
# Writing PCSK9_exome_maf001_cadd_extracted.bim ... done.
# Writing PCSK9_exome_maf001_cadd_extracted.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_exome_maf001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:41 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_hrc_rsq03_maf001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr1_rsq03_maf001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_hrc_rsq03_maf001_cadd_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_hrc_rsq03_maf001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:41 2024
# 515666 MiB RAM detected, ~490271 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr1_rsq03_maf001_LOF_missense_extracted.fam.
# 20551 variants loaded from
# ../hrc/hrc_chr1_rsq03_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 6 variants remaining.
# 6 variants remaining after main filters.
# Writing PCSK9_hrc_rsq03_maf001_cadd_extracted.bim ... done.
# Writing PCSK9_hrc_rsq03_maf001_cadd_extracted.fam ... done.
# Writing PCSK9_hrc_rsq03_maf001_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_hrc_rsq03_maf001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:41 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_topmed_v3_rsq03_maf001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/../topmed_v3/topmed_chr1_rsq03_maf001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_topmed_v3_rsq03_maf001_cadd_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_topmed_v3_rsq03_maf001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:41 2024
# 515666 MiB RAM detected, ~490271 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from
# ../topmed_v3/../topmed_v3/topmed_chr1_rsq03_maf001_LOF_missense_extracted.fam.
# 141967 variants loaded from
# ../topmed_v3/../topmed_v3/topmed_chr1_rsq03_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 61 variants remaining.
# 61 variants remaining after main filters.
# Writing PCSK9_topmed_v3_rsq03_maf001_cadd_extracted.bim ... done.
# Writing PCSK9_topmed_v3_rsq03_maf001_cadd_extracted.fam ... done.
# Writing PCSK9_topmed_v3_rsq03_maf001_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_topmed_v3_rsq03_maf001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:41 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_hrc_rsq08_maf001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr1_rsq08_maf001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_hrc_rsq08_maf001_cadd_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_hrc_rsq08_maf001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:41 2024
# 515666 MiB RAM detected, ~490270 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr1_rsq08_maf001_LOF_missense_extracted.fam.
# 8396 variants loaded from
# ../hrc/hrc_chr1_rsq08_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 2 variants remaining.
# 2 variants remaining after main filters.
# Writing PCSK9_hrc_rsq08_maf001_cadd_extracted.bim ... done.
# Writing PCSK9_hrc_rsq08_maf001_cadd_extracted.fam ... done.
# Writing PCSK9_hrc_rsq08_maf001_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_hrc_rsq08_maf001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:42 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_topmed_v3_rsq08_maf001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/../topmed_v3/topmed_chr1_rsq08_maf001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_topmed_v3_rsq08_maf001_cadd_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_topmed_v3_rsq08_maf001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:42 2024
# 515666 MiB RAM detected, ~490268 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from
# ../topmed_v3/../topmed_v3/topmed_chr1_rsq08_maf001_LOF_missense_extracted.fam.
# 45669 variants loaded from
# ../topmed_v3/../topmed_v3/topmed_chr1_rsq08_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 15 variants remaining.
# 15 variants remaining after main filters.
# Writing PCSK9_topmed_v3_rsq08_maf001_cadd_extracted.bim ... done.
# Writing PCSK9_topmed_v3_rsq08_maf001_cadd_extracted.fam ... done.
# Writing PCSK9_topmed_v3_rsq08_maf001_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_topmed_v3_rsq08_maf001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:42 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_exome_maf0005_cadd_extracted.log.
# Options in effect:
#   --bfile ../exome/ukb23156_c1_maf0005_LOF_missense_extracted
#   --export A
#   --extract PCSK9_exome_maf0005_cadd_extractlist_snplist
#   --make-bed
#   --out PCSK9_exome_maf0005_cadd_extracted
#
# Start time: Fri Jul  5 13:52:42 2024
# 515666 MiB RAM detected, ~490270 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../exome/ukb23156_c1_maf0005_LOF_missense_extracted.fam.
# 477452 variants loaded from
# ../exome/ukb23156_c1_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 200 variants remaining.
# 200 variants remaining after main filters.
# Writing PCSK9_exome_maf0005_cadd_extracted.fam ... done.
# Writing PCSK9_exome_maf0005_cadd_extracted.bim ... done.
# Writing PCSK9_exome_maf0005_cadd_extracted.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_exome_maf0005_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:42 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_hrc_rsq03_maf0005_cadd_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr1_rsq03_maf0005_LOF_missense_extracted
#   --export A
#   --extract PCSK9_hrc_rsq03_maf0005_cadd_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_hrc_rsq03_maf0005_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:42 2024
# 515666 MiB RAM detected, ~490267 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr1_rsq03_maf0005_LOF_missense_extracted.fam.
# 19743 variants loaded from
# ../hrc/hrc_chr1_rsq03_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 6 variants remaining.
# 6 variants remaining after main filters.
# Writing PCSK9_hrc_rsq03_maf0005_cadd_extracted.bim ... done.
# Writing PCSK9_hrc_rsq03_maf0005_cadd_extracted.fam ... done.
# Writing PCSK9_hrc_rsq03_maf0005_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_hrc_rsq03_maf0005_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:42 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_topmed_v3_rsq03_maf0005_cadd_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/../topmed_v3/topmed_chr1_rsq03_maf0005_LOF_missense_extracted
#   --export A
#   --extract PCSK9_topmed_v3_rsq03_maf0005_cadd_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_topmed_v3_rsq03_maf0005_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:42 2024
# 515666 MiB RAM detected, ~490269 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from
# ../topmed_v3/../topmed_v3/topmed_chr1_rsq03_maf0005_LOF_missense_extracted.fam.
# 141141 variants loaded from
# ../topmed_v3/../topmed_v3/topmed_chr1_rsq03_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 61 variants remaining.
# 61 variants remaining after main filters.
# Writing PCSK9_topmed_v3_rsq03_maf0005_cadd_extracted.bim ... done.
# Writing PCSK9_topmed_v3_rsq03_maf0005_cadd_extracted.fam ... done.
# Writing PCSK9_topmed_v3_rsq03_maf0005_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_topmed_v3_rsq03_maf0005_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:42 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_hrc_rsq08_maf0005_cadd_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr1_rsq08_maf0005_LOF_missense_extracted
#   --export A
#   --extract PCSK9_hrc_rsq08_maf0005_cadd_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_hrc_rsq08_maf0005_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:42 2024
# 515666 MiB RAM detected, ~490266 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr1_rsq08_maf0005_LOF_missense_extracted.fam.
# 7666 variants loaded from
# ../hrc/hrc_chr1_rsq08_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 2 variants remaining.
# 2 variants remaining after main filters.
# Writing PCSK9_hrc_rsq08_maf0005_cadd_extracted.bim ... done.
# Writing PCSK9_hrc_rsq08_maf0005_cadd_extracted.fam ... done.
# Writing PCSK9_hrc_rsq08_maf0005_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_hrc_rsq08_maf0005_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:42 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_topmed_v3_rsq08_maf0005_cadd_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/../topmed_v3/topmed_chr1_rsq08_maf0005_LOF_missense_extracted
#   --export A
#   --extract PCSK9_topmed_v3_rsq08_maf0005_cadd_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_topmed_v3_rsq08_maf0005_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:42 2024
# 515666 MiB RAM detected, ~490265 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from
# ../topmed_v3/../topmed_v3/topmed_chr1_rsq08_maf0005_LOF_missense_extracted.fam.
# 44886 variants loaded from
# ../topmed_v3/../topmed_v3/topmed_chr1_rsq08_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 15 variants remaining.
# 15 variants remaining after main filters.
# Writing PCSK9_topmed_v3_rsq08_maf0005_cadd_extracted.bim ... done.
# Writing PCSK9_topmed_v3_rsq08_maf0005_cadd_extracted.fam ... done.
# Writing PCSK9_topmed_v3_rsq08_maf0005_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_topmed_v3_rsq08_maf0005_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:42 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_exome_maf0001_cadd_extracted.log.
# Options in effect:
#   --bfile ../exome/ukb23156_c1_maf0001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_exome_maf0001_cadd_extractlist_snplist
#   --make-bed
#   --out PCSK9_exome_maf0001_cadd_extracted
#
# Start time: Fri Jul  5 13:52:42 2024
# 515666 MiB RAM detected, ~490265 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../exome/ukb23156_c1_maf0001_LOF_missense_extracted.fam.
# 473986 variants loaded from
# ../exome/ukb23156_c1_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 199 variants remaining.
# 199 variants remaining after main filters.
# Writing PCSK9_exome_maf0001_cadd_extracted.fam ... done.
# Writing PCSK9_exome_maf0001_cadd_extracted.bim ... done.
# Writing PCSK9_exome_maf0001_cadd_extracted.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_exome_maf0001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:43 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_hrc_rsq03_maf0001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr1_rsq03_maf0001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_hrc_rsq03_maf0001_cadd_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_hrc_rsq03_maf0001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:43 2024
# 515666 MiB RAM detected, ~490265 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr1_rsq03_maf0001_LOF_missense_extracted.fam.
# 16591 variants loaded from
# ../hrc/hrc_chr1_rsq03_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 5 variants remaining.
# 5 variants remaining after main filters.
# Writing PCSK9_hrc_rsq03_maf0001_cadd_extracted.bim ... done.
# Writing PCSK9_hrc_rsq03_maf0001_cadd_extracted.fam ... done.
# Writing PCSK9_hrc_rsq03_maf0001_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_hrc_rsq03_maf0001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:43 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_topmed_v3_rsq03_maf0001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/../topmed_v3/topmed_chr1_rsq03_maf0001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_topmed_v3_rsq03_maf0001_cadd_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_topmed_v3_rsq03_maf0001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:43 2024
# 515666 MiB RAM detected, ~490264 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from
# ../topmed_v3/../topmed_v3/topmed_chr1_rsq03_maf0001_LOF_missense_extracted.fam.
# 137927 variants loaded from
# ../topmed_v3/../topmed_v3/topmed_chr1_rsq03_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 60 variants remaining.
# 60 variants remaining after main filters.
# Writing PCSK9_topmed_v3_rsq03_maf0001_cadd_extracted.bim ... done.
# Writing PCSK9_topmed_v3_rsq03_maf0001_cadd_extracted.fam ... done.
# Writing PCSK9_topmed_v3_rsq03_maf0001_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_topmed_v3_rsq03_maf0001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:43 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_hrc_rsq08_maf0001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr1_rsq08_maf0001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_hrc_rsq08_maf0001_cadd_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_hrc_rsq08_maf0001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:43 2024
# 515666 MiB RAM detected, ~490263 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr1_rsq08_maf0001_LOF_missense_extracted.fam.
# 5243 variants loaded from
# ../hrc/hrc_chr1_rsq08_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 2 variants remaining.
# 2 variants remaining after main filters.
# Writing PCSK9_hrc_rsq08_maf0001_cadd_extracted.bim ... done.
# Writing PCSK9_hrc_rsq08_maf0001_cadd_extracted.fam ... done.
# Writing PCSK9_hrc_rsq08_maf0001_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_hrc_rsq08_maf0001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:43 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to PCSK9_topmed_v3_rsq08_maf0001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/../topmed_v3/topmed_chr1_rsq08_maf0001_LOF_missense_extracted
#   --export A
#   --extract PCSK9_topmed_v3_rsq08_maf0001_cadd_extractlist_snplist
#   --make-bpgen
#   --out PCSK9_topmed_v3_rsq08_maf0001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:43 2024
# 515666 MiB RAM detected, ~490262 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from
# ../topmed_v3/../topmed_v3/topmed_chr1_rsq08_maf0001_LOF_missense_extracted.fam.
# 42131 variants loaded from
# ../topmed_v3/../topmed_v3/topmed_chr1_rsq08_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 14 variants remaining.
# 14 variants remaining after main filters.
# Writing PCSK9_topmed_v3_rsq08_maf0001_cadd_extracted.bim ... done.
# Writing PCSK9_topmed_v3_rsq08_maf0001_cadd_extracted.fam ... done.
# Writing PCSK9_topmed_v3_rsq08_maf0001_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: PCSK9_topmed_v3_rsq08_maf0001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:52:43 2024

# %%
cd ~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/apoc3

for i in 1 05 01; do
    plink2 \
        --bfile ../exome/ukb23156_c11_maf00${i}_LOF_missense_extracted \
        --extract APOC3_exome_maf00${i}_extractlist_snplist \
        --make-bed --export A \
        --out APOC3_exome_maf00${i}_extracted

    for j in 3 8; do
        plink2 \
            --bpfile ../hrc/hrc_chr11_rsq0${j}_maf00${i}_LOF_missense_extracted \
            --extract APOC3_hrc_rsq0${j}_maf00${i}_extractlist_snplist \
            --make-bpgen --sort-vars \
            --export A \
            --out APOC3_hrc_rsq0${j}_maf00${i}_extracted

        plink2 \
            --bpfile ../topmed_v3/topmed_chr11_rsq0${j}_maf00${i}_LOF_missense_extracted \
            --extract APOC3_topmed_v3_rsq0${j}_maf00${i}_extractlist_snplist \
            --make-bpgen --sort-vars \
            --export A \
            --out APOC3_topmed_v3_rsq0${j}_maf00${i}_extracted
    done
done
# Out:
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_exome_maf001_extracted.log.
# Options in effect:
#   --bfile ../exome/ukb23156_c11_maf001_LOF_missense_extracted
#   --export A
#   --extract APOC3_exome_maf001_extractlist_snplist
#   --make-bed
#   --out APOC3_exome_maf001_extracted
#
# Start time: Fri Jul  5 13:52:52 2024
# 515666 MiB RAM detected, ~490212 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../exome/ukb23156_c11_maf001_LOF_missense_extracted.fam.
# 293784 variants loaded from
# ../exome/ukb23156_c11_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 60 variants remaining.
# 60 variants remaining after main filters.
# Writing APOC3_exome_maf001_extracted.fam ... done.
# Writing APOC3_exome_maf001_extracted.bim ... done.
# Writing APOC3_exome_maf001_extracted.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_exome_maf001_extracted.raw written.
# End time: Fri Jul  5 13:52:57 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_hrc_rsq03_maf001_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr11_rsq03_maf001_LOF_missense_extracted
#   --export A
#   --extract APOC3_hrc_rsq03_maf001_extractlist_snplist
#   --make-bpgen
#   --out APOC3_hrc_rsq03_maf001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:57 2024
# 515666 MiB RAM detected, ~490185 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr11_rsq03_maf001_LOF_missense_extracted.fam.
# 13392 variants loaded from
# ../hrc/hrc_chr11_rsq03_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 3 variants remaining.
# 3 variants remaining after main filters.
# Writing APOC3_hrc_rsq03_maf001_extracted.bim ... done.
# Writing APOC3_hrc_rsq03_maf001_extracted.fam ... done.
# Writing APOC3_hrc_rsq03_maf001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_hrc_rsq03_maf001_extracted.raw written.
# End time: Fri Jul  5 13:52:58 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_topmed_v3_rsq03_maf001_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr11_rsq03_maf001_LOF_missense_extracted
#   --export A
#   --extract APOC3_topmed_v3_rsq03_maf001_extractlist_snplist
#   --make-bpgen
#   --out APOC3_topmed_v3_rsq03_maf001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:52:58 2024
# 515666 MiB RAM detected, ~490179 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr11_rsq03_maf001_LOF_missense_extracted.fam.
# 88634 variants loaded from
# ../topmed_v3/topmed_chr11_rsq03_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 18 variants remaining.
# 18 variants remaining after main filters.
# Writing APOC3_topmed_v3_rsq03_maf001_extracted.bim ... done.
# Writing APOC3_topmed_v3_rsq03_maf001_extracted.fam ... done.
# Writing APOC3_topmed_v3_rsq03_maf001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_topmed_v3_rsq03_maf001_extracted.raw written.
# End time: Fri Jul  5 13:53:00 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_hrc_rsq08_maf001_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr11_rsq08_maf001_LOF_missense_extracted
#   --export A
#   --extract APOC3_hrc_rsq08_maf001_extractlist_snplist
#   --make-bpgen
#   --out APOC3_hrc_rsq08_maf001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:00 2024
# 515666 MiB RAM detected, ~490168 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr11_rsq08_maf001_LOF_missense_extracted.fam.
# 5811 variants loaded from
# ../hrc/hrc_chr11_rsq08_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 2 variants remaining.
# 2 variants remaining after main filters.
# Writing APOC3_hrc_rsq08_maf001_extracted.bim ... done.
# Writing APOC3_hrc_rsq08_maf001_extracted.fam ... done.
# Writing APOC3_hrc_rsq08_maf001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_hrc_rsq08_maf001_extracted.raw written.
# End time: Fri Jul  5 13:53:01 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_topmed_v3_rsq08_maf001_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr11_rsq08_maf001_LOF_missense_extracted
#   --export A
#   --extract APOC3_topmed_v3_rsq08_maf001_extractlist_snplist
#   --make-bpgen
#   --out APOC3_topmed_v3_rsq08_maf001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:01 2024
# 515666 MiB RAM detected, ~490161 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr11_rsq08_maf001_LOF_missense_extracted.fam.
# 29328 variants loaded from
# ../topmed_v3/topmed_chr11_rsq08_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 4 variants remaining.
# 4 variants remaining after main filters.
# Writing APOC3_topmed_v3_rsq08_maf001_extracted.bim ... done.
# Writing APOC3_topmed_v3_rsq08_maf001_extracted.fam ... done.
# Writing APOC3_topmed_v3_rsq08_maf001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_topmed_v3_rsq08_maf001_extracted.raw written.
# End time: Fri Jul  5 13:53:03 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_exome_maf0005_extracted.log.
# Options in effect:
#   --bfile ../exome/ukb23156_c11_maf0005_LOF_missense_extracted
#   --export A
#   --extract APOC3_exome_maf0005_extractlist_snplist
#   --make-bed
#   --out APOC3_exome_maf0005_extracted
#
# Start time: Fri Jul  5 13:53:03 2024
# 515666 MiB RAM detected, ~490148 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../exome/ukb23156_c11_maf0005_LOF_missense_extracted.fam.
# 293221 variants loaded from
# ../exome/ukb23156_c11_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 60 variants remaining.
# 60 variants remaining after main filters.
# Writing APOC3_exome_maf0005_extracted.fam ... done.
# Writing APOC3_exome_maf0005_extracted.bim ... done.
# Writing APOC3_exome_maf0005_extracted.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_exome_maf0005_extracted.raw written.
# End time: Fri Jul  5 13:53:07 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_hrc_rsq03_maf0005_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr11_rsq03_maf0005_LOF_missense_extracted
#   --export A
#   --extract APOC3_hrc_rsq03_maf0005_extractlist_snplist
#   --make-bpgen
#   --out APOC3_hrc_rsq03_maf0005_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:07 2024
# 515666 MiB RAM detected, ~490124 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr11_rsq03_maf0005_LOF_missense_extracted.fam.
# 12867 variants loaded from
# ../hrc/hrc_chr11_rsq03_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 3 variants remaining.
# 3 variants remaining after main filters.
# Writing APOC3_hrc_rsq03_maf0005_extracted.bim ... done.
# Writing APOC3_hrc_rsq03_maf0005_extracted.fam ... done.
# Writing APOC3_hrc_rsq03_maf0005_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_hrc_rsq03_maf0005_extracted.raw written.
# End time: Fri Jul  5 13:53:11 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_topmed_v3_rsq03_maf0005_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr11_rsq03_maf0005_LOF_missense_extracted
#   --export A
#   --extract APOC3_topmed_v3_rsq03_maf0005_extractlist_snplist
#   --make-bpgen
#   --out APOC3_topmed_v3_rsq03_maf0005_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:11 2024
# 515666 MiB RAM detected, ~490105 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr11_rsq03_maf0005_LOF_missense_extracted.fam.
# 88110 variants loaded from
# ../topmed_v3/topmed_chr11_rsq03_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 18 variants remaining.
# 18 variants remaining after main filters.
# Writing APOC3_topmed_v3_rsq03_maf0005_extracted.bim ... done.
# Writing APOC3_topmed_v3_rsq03_maf0005_extracted.fam ... done.
# Writing APOC3_topmed_v3_rsq03_maf0005_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_topmed_v3_rsq03_maf0005_extracted.raw written.
# End time: Fri Jul  5 13:53:13 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_hrc_rsq08_maf0005_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr11_rsq08_maf0005_LOF_missense_extracted
#   --export A
#   --extract APOC3_hrc_rsq08_maf0005_extractlist_snplist
#   --make-bpgen
#   --out APOC3_hrc_rsq08_maf0005_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:13 2024
# 515666 MiB RAM detected, ~490374 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr11_rsq08_maf0005_LOF_missense_extracted.fam.
# 5315 variants loaded from
# ../hrc/hrc_chr11_rsq08_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 2 variants remaining.
# 2 variants remaining after main filters.
# Writing APOC3_hrc_rsq08_maf0005_extracted.bim ... done.
# Writing APOC3_hrc_rsq08_maf0005_extracted.fam ... done.
# Writing APOC3_hrc_rsq08_maf0005_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_hrc_rsq08_maf0005_extracted.raw written.
# End time: Fri Jul  5 13:53:15 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_topmed_v3_rsq08_maf0005_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr11_rsq08_maf0005_LOF_missense_extracted
#   --export A
#   --extract APOC3_topmed_v3_rsq08_maf0005_extractlist_snplist
#   --make-bpgen
#   --out APOC3_topmed_v3_rsq08_maf0005_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:15 2024
# 515666 MiB RAM detected, ~490366 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr11_rsq08_maf0005_LOF_missense_extracted.fam.
# 28822 variants loaded from
# ../topmed_v3/topmed_chr11_rsq08_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 4 variants remaining.
# 4 variants remaining after main filters.
# Writing APOC3_topmed_v3_rsq08_maf0005_extracted.bim ... done.
# Writing APOC3_topmed_v3_rsq08_maf0005_extracted.fam ... done.
# Writing APOC3_topmed_v3_rsq08_maf0005_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_topmed_v3_rsq08_maf0005_extracted.raw written.
# End time: Fri Jul  5 13:53:17 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_exome_maf0001_extracted.log.
# Options in effect:
#   --bfile ../exome/ukb23156_c11_maf0001_LOF_missense_extracted
#   --export A
#   --extract APOC3_exome_maf0001_extractlist_snplist
#   --make-bed
#   --out APOC3_exome_maf0001_extracted
#
# Start time: Fri Jul  5 13:53:17 2024
# 515666 MiB RAM detected, ~490353 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../exome/ukb23156_c11_maf0001_LOF_missense_extracted.fam.
# 291093 variants loaded from
# ../exome/ukb23156_c11_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 59 variants remaining.
# 59 variants remaining after main filters.
# Writing APOC3_exome_maf0001_extracted.fam ... done.
# Writing APOC3_exome_maf0001_extracted.bim ... done.
# Writing APOC3_exome_maf0001_extracted.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_exome_maf0001_extracted.raw written.
# End time: Fri Jul  5 13:53:21 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_hrc_rsq03_maf0001_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr11_rsq03_maf0001_LOF_missense_extracted
#   --export A
#   --extract APOC3_hrc_rsq03_maf0001_extractlist_snplist
#   --make-bpgen
#   --out APOC3_hrc_rsq03_maf0001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:21 2024
# 515666 MiB RAM detected, ~490332 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr11_rsq03_maf0001_LOF_missense_extracted.fam.
# 10872 variants loaded from
# ../hrc/hrc_chr11_rsq03_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 2 variants remaining.
# 2 variants remaining after main filters.
# Writing APOC3_hrc_rsq03_maf0001_extracted.bim ... done.
# Writing APOC3_hrc_rsq03_maf0001_extracted.fam ... done.
# Writing APOC3_hrc_rsq03_maf0001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_hrc_rsq03_maf0001_extracted.raw written.
# End time: Fri Jul  5 13:53:23 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_topmed_v3_rsq03_maf0001_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr11_rsq03_maf0001_LOF_missense_extracted
#   --export A
#   --extract APOC3_topmed_v3_rsq03_maf0001_extractlist_snplist
#   --make-bpgen
#   --out APOC3_topmed_v3_rsq03_maf0001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:23 2024
# 515666 MiB RAM detected, ~490320 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr11_rsq03_maf0001_LOF_missense_extracted.fam.
# 86113 variants loaded from
# ../topmed_v3/topmed_chr11_rsq03_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 17 variants remaining.
# 17 variants remaining after main filters.
# Writing APOC3_topmed_v3_rsq03_maf0001_extracted.bim ... done.
# Writing APOC3_topmed_v3_rsq03_maf0001_extracted.fam ... done.
# Writing APOC3_topmed_v3_rsq03_maf0001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_topmed_v3_rsq03_maf0001_extracted.raw written.
# End time: Fri Jul  5 13:53:25 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_hrc_rsq08_maf0001_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr11_rsq08_maf0001_LOF_missense_extracted
#   --export A
#   --extract APOC3_hrc_rsq08_maf0001_extractlist_snplist
#   --make-bpgen
#   --out APOC3_hrc_rsq08_maf0001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:25 2024
# 515666 MiB RAM detected, ~490309 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr11_rsq08_maf0001_LOF_missense_extracted.fam.
# 3788 variants loaded from
# ../hrc/hrc_chr11_rsq08_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 0 variants remaining.
# Error: No variants remaining after main filters.
# End time: Fri Jul  5 13:53:26 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_topmed_v3_rsq08_maf0001_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr11_rsq08_maf0001_LOF_missense_extracted
#   --export A
#   --extract APOC3_topmed_v3_rsq08_maf0001_extractlist_snplist
#   --make-bpgen
#   --out APOC3_topmed_v3_rsq08_maf0001_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:26 2024
# 515666 MiB RAM detected, ~490302 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr11_rsq08_maf0001_LOF_missense_extracted.fam.
# 27096 variants loaded from
# ../topmed_v3/topmed_chr11_rsq08_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 3 variants remaining.
# 3 variants remaining after main filters.
# Writing APOC3_topmed_v3_rsq08_maf0001_extracted.bim ... done.
# Writing APOC3_topmed_v3_rsq08_maf0001_extracted.fam ... done.
# Writing APOC3_topmed_v3_rsq08_maf0001_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_topmed_v3_rsq08_maf0001_extracted.raw written.
# End time: Fri Jul  5 13:53:28 2024

# %%
for i in 1 05 01; do
    plink2 \
        --bfile ../exome/ukb23156_c11_maf00${i}_LOF_missense_extracted \
        --extract APOC3_exome_maf00${i}_cadd_extractlist_snplist \
        --make-bed --export A \
        --out APOC3_exome_maf00${i}_cadd_extracted

    for j in 3 8; do
        plink2 \
            --bpfile ../hrc/hrc_chr11_rsq0${j}_maf00${i}_LOF_missense_extracted \
            --extract APOC3_hrc_rsq0${j}_maf00${i}_cadd_extractlist_snplist \
            --make-bpgen --sort-vars \
            --export A \
            --out APOC3_hrc_rsq0${j}_maf00${i}_cadd_extracted

        plink2 \
            --bpfile ../topmed_v3/topmed_chr1_rsq0${j}_maf00${i}_LOF_missense_extracted \
            --extract APOC3_topmed_v3_rsq0${j}_maf00${i}_cadd_extractlist_snplist \
            --make-bpgen --sort-vars \
            --export A \
            --out APOC3_topmed_v3_rsq0${j}_maf00${i}_cadd_extracted
    done
done
# Out:
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_exome_maf001_cadd_extracted.log.
# Options in effect:
#   --bfile ../exome/ukb23156_c11_maf001_LOF_missense_extracted
#   --export A
#   --extract APOC3_exome_maf001_cadd_extractlist_snplist
#   --make-bed
#   --out APOC3_exome_maf001_cadd_extracted
#
# Start time: Fri Jul  5 13:53:33 2024
# 515666 MiB RAM detected, ~490265 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../exome/ukb23156_c11_maf001_LOF_missense_extracted.fam.
# 293784 variants loaded from
# ../exome/ukb23156_c11_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 26 variants remaining.
# 26 variants remaining after main filters.
# Writing APOC3_exome_maf001_cadd_extracted.fam ... done.
# Writing APOC3_exome_maf001_cadd_extracted.bim ... done.
# Writing APOC3_exome_maf001_cadd_extracted.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_exome_maf001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:53:33 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_hrc_rsq03_maf001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr11_rsq03_maf001_LOF_missense_extracted
#   --export A
#   --extract APOC3_hrc_rsq03_maf001_cadd_extractlist_snplist
#   --make-bpgen
#   --out APOC3_hrc_rsq03_maf001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:33 2024
# 515666 MiB RAM detected, ~490265 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr11_rsq03_maf001_LOF_missense_extracted.fam.
# 13392 variants loaded from
# ../hrc/hrc_chr11_rsq03_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 3 variants remaining.
# 3 variants remaining after main filters.
# Writing APOC3_hrc_rsq03_maf001_cadd_extracted.bim ... done.
# Writing APOC3_hrc_rsq03_maf001_cadd_extracted.fam ... done.
# Writing APOC3_hrc_rsq03_maf001_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_hrc_rsq03_maf001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:53:33 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_topmed_v3_rsq03_maf001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr1_rsq03_maf001_LOF_missense_extracted
#   --export A
#   --extract APOC3_topmed_v3_rsq03_maf001_cadd_extractlist_snplist
#   --make-bpgen
#   --out APOC3_topmed_v3_rsq03_maf001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:33 2024
# 515666 MiB RAM detected, ~490262 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr1_rsq03_maf001_LOF_missense_extracted.fam.
# 141967 variants loaded from
# ../topmed_v3/topmed_chr1_rsq03_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 0 variants remaining.
# Error: No variants remaining after main filters.
# End time: Fri Jul  5 13:53:33 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_hrc_rsq08_maf001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr11_rsq08_maf001_LOF_missense_extracted
#   --export A
#   --extract APOC3_hrc_rsq08_maf001_cadd_extractlist_snplist
#   --make-bpgen
#   --out APOC3_hrc_rsq08_maf001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:33 2024
# 515666 MiB RAM detected, ~490260 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr11_rsq08_maf001_LOF_missense_extracted.fam.
# 5811 variants loaded from
# ../hrc/hrc_chr11_rsq08_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 2 variants remaining.
# 2 variants remaining after main filters.
# Writing APOC3_hrc_rsq08_maf001_cadd_extracted.bim ... done.
# Writing APOC3_hrc_rsq08_maf001_cadd_extracted.fam ... done.
# Writing APOC3_hrc_rsq08_maf001_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_hrc_rsq08_maf001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:53:33 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_topmed_v3_rsq08_maf001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr1_rsq08_maf001_LOF_missense_extracted
#   --export A
#   --extract APOC3_topmed_v3_rsq08_maf001_cadd_extractlist_snplist
#   --make-bpgen
#   --out APOC3_topmed_v3_rsq08_maf001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:33 2024
# 515666 MiB RAM detected, ~490260 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr1_rsq08_maf001_LOF_missense_extracted.fam.
# 45669 variants loaded from
# ../topmed_v3/topmed_chr1_rsq08_maf001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 0 variants remaining.
# Error: No variants remaining after main filters.
# End time: Fri Jul  5 13:53:33 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_exome_maf0005_cadd_extracted.log.
# Options in effect:
#   --bfile ../exome/ukb23156_c11_maf0005_LOF_missense_extracted
#   --export A
#   --extract APOC3_exome_maf0005_cadd_extractlist_snplist
#   --make-bed
#   --out APOC3_exome_maf0005_cadd_extracted
#
# Start time: Fri Jul  5 13:53:33 2024
# 515666 MiB RAM detected, ~490260 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../exome/ukb23156_c11_maf0005_LOF_missense_extracted.fam.
# 293221 variants loaded from
# ../exome/ukb23156_c11_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 26 variants remaining.
# 26 variants remaining after main filters.
# Writing APOC3_exome_maf0005_cadd_extracted.fam ... done.
# Writing APOC3_exome_maf0005_cadd_extracted.bim ... done.
# Writing APOC3_exome_maf0005_cadd_extracted.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_exome_maf0005_cadd_extracted.raw written.
# End time: Fri Jul  5 13:53:33 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_hrc_rsq03_maf0005_cadd_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr11_rsq03_maf0005_LOF_missense_extracted
#   --export A
#   --extract APOC3_hrc_rsq03_maf0005_cadd_extractlist_snplist
#   --make-bpgen
#   --out APOC3_hrc_rsq03_maf0005_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:33 2024
# 515666 MiB RAM detected, ~490260 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr11_rsq03_maf0005_LOF_missense_extracted.fam.
# 12867 variants loaded from
# ../hrc/hrc_chr11_rsq03_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 3 variants remaining.
# 3 variants remaining after main filters.
# Writing APOC3_hrc_rsq03_maf0005_cadd_extracted.bim ... done.
# Writing APOC3_hrc_rsq03_maf0005_cadd_extracted.fam ... done.
# Writing APOC3_hrc_rsq03_maf0005_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_hrc_rsq03_maf0005_cadd_extracted.raw written.
# End time: Fri Jul  5 13:53:33 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_topmed_v3_rsq03_maf0005_cadd_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr1_rsq03_maf0005_LOF_missense_extracted
#   --export A
#   --extract APOC3_topmed_v3_rsq03_maf0005_cadd_extractlist_snplist
#   --make-bpgen
#   --out APOC3_topmed_v3_rsq03_maf0005_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:33 2024
# 515666 MiB RAM detected, ~490256 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr1_rsq03_maf0005_LOF_missense_extracted.fam.
# 141141 variants loaded from
# ../topmed_v3/topmed_chr1_rsq03_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 0 variants remaining.
# Error: No variants remaining after main filters.
# End time: Fri Jul  5 13:53:34 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_hrc_rsq08_maf0005_cadd_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr11_rsq08_maf0005_LOF_missense_extracted
#   --export A
#   --extract APOC3_hrc_rsq08_maf0005_cadd_extractlist_snplist
#   --make-bpgen
#   --out APOC3_hrc_rsq08_maf0005_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:34 2024
# 515666 MiB RAM detected, ~490257 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr11_rsq08_maf0005_LOF_missense_extracted.fam.
# 5315 variants loaded from
# ../hrc/hrc_chr11_rsq08_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 2 variants remaining.
# 2 variants remaining after main filters.
# Writing APOC3_hrc_rsq08_maf0005_cadd_extracted.bim ... done.
# Writing APOC3_hrc_rsq08_maf0005_cadd_extracted.fam ... done.
# Writing APOC3_hrc_rsq08_maf0005_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_hrc_rsq08_maf0005_cadd_extracted.raw written.
# End time: Fri Jul  5 13:53:34 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_topmed_v3_rsq08_maf0005_cadd_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr1_rsq08_maf0005_LOF_missense_extracted
#   --export A
#   --extract APOC3_topmed_v3_rsq08_maf0005_cadd_extractlist_snplist
#   --make-bpgen
#   --out APOC3_topmed_v3_rsq08_maf0005_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:34 2024
# 515666 MiB RAM detected, ~490259 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr1_rsq08_maf0005_LOF_missense_extracted.fam.
# 44886 variants loaded from
# ../topmed_v3/topmed_chr1_rsq08_maf0005_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 0 variants remaining.
# Error: No variants remaining after main filters.
# End time: Fri Jul  5 13:53:34 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_exome_maf0001_cadd_extracted.log.
# Options in effect:
#   --bfile ../exome/ukb23156_c11_maf0001_LOF_missense_extracted
#   --export A
#   --extract APOC3_exome_maf0001_cadd_extractlist_snplist
#   --make-bed
#   --out APOC3_exome_maf0001_cadd_extracted
#
# Start time: Fri Jul  5 13:53:34 2024
# 515666 MiB RAM detected, ~490258 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../exome/ukb23156_c11_maf0001_LOF_missense_extracted.fam.
# 291093 variants loaded from
# ../exome/ukb23156_c11_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 25 variants remaining.
# 25 variants remaining after main filters.
# Writing APOC3_exome_maf0001_cadd_extracted.fam ... done.
# Writing APOC3_exome_maf0001_cadd_extracted.bim ... done.
# Writing APOC3_exome_maf0001_cadd_extracted.bed ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_exome_maf0001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:53:34 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_hrc_rsq03_maf0001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr11_rsq03_maf0001_LOF_missense_extracted
#   --export A
#   --extract APOC3_hrc_rsq03_maf0001_cadd_extractlist_snplist
#   --make-bpgen
#   --out APOC3_hrc_rsq03_maf0001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:34 2024
# 515666 MiB RAM detected, ~490258 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr11_rsq03_maf0001_LOF_missense_extracted.fam.
# 10872 variants loaded from
# ../hrc/hrc_chr11_rsq03_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 2 variants remaining.
# 2 variants remaining after main filters.
# Writing APOC3_hrc_rsq03_maf0001_cadd_extracted.bim ... done.
# Writing APOC3_hrc_rsq03_maf0001_cadd_extracted.fam ... done.
# Writing APOC3_hrc_rsq03_maf0001_cadd_extracted.pgen ... done.
# --export A pass 1/1: loading... 0writing... .
# --export A: APOC3_hrc_rsq03_maf0001_cadd_extracted.raw written.
# End time: Fri Jul  5 13:53:34 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_topmed_v3_rsq03_maf0001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr1_rsq03_maf0001_LOF_missense_extracted
#   --export A
#   --extract APOC3_topmed_v3_rsq03_maf0001_cadd_extractlist_snplist
#   --make-bpgen
#   --out APOC3_topmed_v3_rsq03_maf0001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:34 2024
# 515666 MiB RAM detected, ~490254 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr1_rsq03_maf0001_LOF_missense_extracted.fam.
# 137927 variants loaded from
# ../topmed_v3/topmed_chr1_rsq03_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 0 variants remaining.
# Error: No variants remaining after main filters.
# End time: Fri Jul  5 13:53:34 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_hrc_rsq08_maf0001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../hrc/hrc_chr11_rsq08_maf0001_LOF_missense_extracted
#   --export A
#   --extract APOC3_hrc_rsq08_maf0001_cadd_extractlist_snplist
#   --make-bpgen
#   --out APOC3_hrc_rsq08_maf0001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:34 2024
# 515666 MiB RAM detected, ~490253 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../hrc/hrc_chr11_rsq08_maf0001_LOF_missense_extracted.fam.
# 3788 variants loaded from
# ../hrc/hrc_chr11_rsq08_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 0 variants remaining.
# Error: No variants remaining after main filters.
# End time: Fri Jul  5 13:53:34 2024
# PLINK v2.00a4LM 64-bit Intel (11 Apr 2023)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to APOC3_topmed_v3_rsq08_maf0001_cadd_extracted.log.
# Options in effect:
#   --bpfile ../topmed_v3/topmed_chr1_rsq08_maf0001_LOF_missense_extracted
#   --export A
#   --extract APOC3_topmed_v3_rsq08_maf0001_cadd_extractlist_snplist
#   --make-bpgen
#   --out APOC3_topmed_v3_rsq08_maf0001_cadd_extracted
#   --sort-vars
#
# Start time: Fri Jul  5 13:53:34 2024
# 515666 MiB RAM detected, ~490250 available; reserving 257833 MiB for main
# workspace.
# Using up to 2 compute threads.
# 168206 samples (0 females, 0 males, 168206 ambiguous; 168206 founders) loaded
# from ../topmed_v3/topmed_chr1_rsq08_maf0001_LOF_missense_extracted.fam.
# 42131 variants loaded from
# ../topmed_v3/topmed_chr1_rsq08_maf0001_LOF_missense_extracted.bim.
# Note: No phenotype data present.
# --extract: 0 variants remaining.
# Error: No variants remaining after main filters.
# End time: Fri Jul  5 13:53:34 2024
# : 13

# %% [markdown]
# ## Make merged dataset

# %% [markdown]
# ### PCSK9 - exome + topmed + hrc

# %%
setwd("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/pcsk9")

library(dplyr)
library(data.table)
library(tidyverse)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.5.1     ✔ purrr   1.0.2
# ✔ tibble  3.2.1     ✔ stringr 1.5.1
# ✔ tidyr   1.3.1     ✔ forcats 1.0.0
# ✔ readr   2.1.5
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ data.table::between() masks dplyr::between()
# ✖ dplyr::filter()       masks stats::filter()
# ✖ data.table::first()   masks dplyr::first()
# ✖ dplyr::lag()          masks stats::lag()
# ✖ data.table::last()    masks dplyr::last()
# ✖ purrr::transpose()    masks data.table::transpose()

# %%
for(rsq in c(3, 8)){
    for(maf in c("1", "05", "01")){
        for(cadd in c("", "_cadd")){
            print(sprintf("==========RSQ 0.%d; MAF 00%s; CADD filtering:%s", rsq, maf, cadd))
            
            annot_fname <- sprintf("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/hrc_topmed_exome/hrc_topmed_v3_exome_168206ids_rsq0%d_maf00%s%s_annot.csv.gz", 
                       rsq, maf, cadd)
            annot_gene <- read.table(annot_fname, sep = ",", header = TRUE) %>% filter(Gene.refGene == "PCSK9") %>% unique()
            
            full_df <- read.table("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/id_only.csv", sep = ",", header = TRUE)
            
            exome_fname <- sprintf("PCSK9_exome_maf00%s%s_extracted.raw", maf, cadd)
            hrc_fname <- sprintf("PCSK9_hrc_rsq0%d_maf00%s%s_extracted.raw", rsq, maf, cadd)
            topmed_fname <- sprintf("PCSK9_topmed_v3_rsq0%d_maf00%s%s_extracted.raw", rsq, maf, cadd)

            hrc_snplist <- annot_gene %>% filter(source == "hrc") %>% pull(ID_hg19)
            topmed_snplist <- annot_gene %>% filter(source == "topmed") %>% pull(ID)
            
            ## exome matrix
            if(file.exists(exome_fname)){
                exome <- read.table(exome_fname, sep = "\t", header = TRUE) %>% arrange(FID, IID)
                exome_names <- colnames(exome)[7: dim(exome)[2]] %>% 
                    stringr::str_split(pattern = "_", simplify = TRUE)
                exome_names <- stringr::str_replace_all(exome_names[,1], "\\.", ":")
                colnames(exome)[7:dim(exome)[2]] <- exome_names

                full_df <- left_join(full_df, exome)
            }
            
            ## hrc matrix
            if(file.exists(hrc_fname)){
                hrc <- read.table(hrc_fname, sep = "\t", header = TRUE)
                hrc_names <- colnames(hrc)[7: dim(hrc)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
                hrc_names <- stringr::str_replace_all(hrc_names[,1], "\\.", ":")
                colnames(hrc)[7:dim(hrc)[2]] <- hrc_names

                fid_iid <- hrc$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
                hrc$FID <- as.integer(fid_iid[,1])
                hrc$IID <- as.integer(fid_iid[,2])

                hrc <- hrc %>% arrange(FID, IID) %>% select(c("FID", "IID", "PAT", "MAT", "SEX", "PHENOTYPE", hrc_snplist))
                full_df <- left_join(full_df, hrc)
            }
            
            ## topmed matrix
            if(file.exists(topmed_fname)){
                topmed <- read.table(topmed_fname, sep = "\t", header = TRUE)
                topmed_names <- colnames(topmed)[7: dim(topmed)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
                topmed_names <- stringr::str_replace_all(topmed_names[,1], "\\.", ":")
                colnames(topmed)[7:dim(topmed)[2]] <- topmed_names

                fid_iid <- topmed$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
                topmed$FID <- as.integer(fid_iid[,1])
                topmed$IID <- as.integer(fid_iid[,2])

                topmed <- topmed %>% arrange(FID, IID) %>% select(c("FID", "IID", "PAT", "MAT", "SEX", "PHENOTYPE", topmed_snplist))
                full_df <- left_join(full_df, topmed)
            }
            
            fwrite(full_df, sprintf("PCSK9_hrc_topmed_v3_exome_rsq0%d_maf00%s%s_extracted.raw", rsq, maf, cadd))
            
            print(sprintf("HRC_snplist: %d; TOPMed_v3_snplist: %d; Exome: %d; Annot_gene: %d; Full dataframe: %d", 
                          length(hrc_snplist), length(topmed_snplist), ncol(exome)-6, nrow(annot_gene), ncol(full_df)-6))
            rm(full_df)
        }
    }
}
# Out:
# [1] "==========RSQ 0.3; MAF 001; CADD filtering:"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 2; TOPMed_v3_snplist: 16; Exome: 394; Annot_gene: 412; Full dataframe: 412"
# [1] "==========RSQ 0.3; MAF 001; CADD filtering:_cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 1; TOPMed_v3_snplist: 3; Exome: 200; Annot_gene: 204; Full dataframe: 204"
# [1] "==========RSQ 0.3; MAF 0005; CADD filtering:"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 2; TOPMed_v3_snplist: 16; Exome: 394; Annot_gene: 412; Full dataframe: 412"
# [1] "==========RSQ 0.3; MAF 0005; CADD filtering:_cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 1; TOPMed_v3_snplist: 3; Exome: 200; Annot_gene: 204; Full dataframe: 204"
# [1] "==========RSQ 0.3; MAF 0001; CADD filtering:"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 2; TOPMed_v3_snplist: 16; Exome: 393; Annot_gene: 411; Full dataframe: 411"
# [1] "==========RSQ 0.3; MAF 0001; CADD filtering:_cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 1; TOPMed_v3_snplist: 3; Exome: 199; Annot_gene: 203; Full dataframe: 203"
# [1] "==========RSQ 0.8; MAF 001; CADD filtering:"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 0; Exome: 394; Annot_gene: 394; Full dataframe: 394"
# [1] "==========RSQ 0.8; MAF 001; CADD filtering:_cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 0; Exome: 200; Annot_gene: 200; Full dataframe: 200"
# [1] "==========RSQ 0.8; MAF 0005; CADD filtering:"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 0; Exome: 394; Annot_gene: 394; Full dataframe: 394"
# [1] "==========RSQ 0.8; MAF 0005; CADD filtering:_cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 0; Exome: 200; Annot_gene: 200; Full dataframe: 200"
# [1] "==========RSQ 0.8; MAF 0001; CADD filtering:"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 0; Exome: 393; Annot_gene: 393; Full dataframe: 393"
# [1] "==========RSQ 0.8; MAF 0001; CADD filtering:_cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 0; Exome: 199; Annot_gene: 199; Full dataframe: 199"

# %% [markdown]
# ### PCSK9 - topmed + hrc

# %%
for(rsq in c(3, 8)){
    for(maf in c("1", "05", "01")){
        for(cadd in c("", "_cadd")){
            print(sprintf("==========RSQ 0.%d; MAF 00%s; CADD filtering: %s", rsq, maf, cadd))
            annot_fname <- sprintf("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/hrc_topmed/hrc_topmed_v3_168206ids_rsq0%d_maf00%s%s_annot.csv.gz", 
                                   rsq, maf, cadd)
            annot_gene <- read.table(annot_fname, sep = ",", header = TRUE) %>% filter(Gene.refGene == "PCSK9") %>% unique()
            
            full_df <- read.table("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/id_only.csv", sep = ",", header = TRUE)            
            hrc_fname <- sprintf("PCSK9_hrc_rsq0%d_maf00%s%s_extracted.raw", rsq, maf, cadd)
            topmed_fname <- sprintf("PCSK9_topmed_v3_rsq0%d_maf00%s%s_extracted.raw", rsq, maf, cadd)
            
            hrc_snplist <- annot_gene %>% filter(source == "hrc") %>% pull(ID_hg19)
            topmed_snplist <- annot_gene %>% filter(source == "topmed") %>% pull(ID)

            ## hrc matrix
            if(file.exists(hrc_fname)){
                hrc <- read.table(hrc_fname, sep = "\t", header = TRUE)
                hrc_names <- colnames(hrc)[7: dim(hrc)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
                hrc_names <- stringr::str_replace_all(hrc_names[,1], "\\.", ":")
                colnames(hrc)[7:dim(hrc)[2]] <- hrc_names

                fid_iid <- hrc$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
                hrc$FID <- as.integer(fid_iid[,1])
                hrc$IID <- as.integer(fid_iid[,2])

                hrc <- hrc %>% arrange(FID, IID) %>% select(c("FID", "IID", "PAT", "MAT", "SEX", "PHENOTYPE", hrc_snplist))
                full_df <- left_join(full_df, hrc)
            }
            
            ## topmed matrix
            if(file.exists(topmed_fname)){
                topmed <- read.table(topmed_fname, sep = "\t", header = TRUE)
                topmed_names <- colnames(topmed)[7: dim(topmed)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
                topmed_names <- stringr::str_replace_all(topmed_names[,1], "\\.", ":")
                colnames(topmed)[7:dim(topmed)[2]] <- topmed_names

                fid_iid <- topmed$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
                topmed$FID <- as.integer(fid_iid[,1])
                topmed$IID <- as.integer(fid_iid[,2])

                topmed <- topmed %>% arrange(FID, IID) %>% select(c("FID", "IID", "PAT", "MAT", "SEX", "PHENOTYPE", topmed_snplist))
                full_df <- left_join(full_df, topmed)
            }
            
            fwrite(full_df, sprintf("PCSK9_hrc_topmed_v3_rsq0%d_maf00%s%s_extracted.raw", rsq, maf, cadd))
            
            print(sprintf("HRC_snplist: %d; TOPMed_v3_snplist: %d; Annot_gene: %d; Full dataframe: %d", 
                          length(hrc_snplist), length(topmed_snplist), nrow(annot_gene), ncol(full_df)-6))
        }
    }
}
# Out:
# [1] "==========RSQ 0.3; MAF 001; CADD filtering: "
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 10; TOPMed_v3_snplist: 115; Annot_gene: 125; Full dataframe: 125"
# [1] "==========RSQ 0.3; MAF 001; CADD filtering: _cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 4; TOPMed_v3_snplist: 57; Annot_gene: 61; Full dataframe: 61"
# [1] "==========RSQ 0.3; MAF 0005; CADD filtering: "
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 10; TOPMed_v3_snplist: 115; Annot_gene: 125; Full dataframe: 125"
# [1] "==========RSQ 0.3; MAF 0005; CADD filtering: _cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 4; TOPMed_v3_snplist: 57; Annot_gene: 61; Full dataframe: 61"
# [1] "==========RSQ 0.3; MAF 0001; CADD filtering: "
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 10; TOPMed_v3_snplist: 114; Annot_gene: 124; Full dataframe: 124"
# [1] "==========RSQ 0.3; MAF 0001; CADD filtering: _cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 4; TOPMed_v3_snplist: 56; Annot_gene: 60; Full dataframe: 60"
# [1] "==========RSQ 0.8; MAF 001; CADD filtering: "
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 4; TOPMed_v3_snplist: 34; Annot_gene: 38; Full dataframe: 38"
# [1] "==========RSQ 0.8; MAF 001; CADD filtering: _cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 1; TOPMed_v3_snplist: 15; Annot_gene: 16; Full dataframe: 16"
# [1] "==========RSQ 0.8; MAF 0005; CADD filtering: "
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 4; TOPMed_v3_snplist: 34; Annot_gene: 38; Full dataframe: 38"
# [1] "==========RSQ 0.8; MAF 0005; CADD filtering: _cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 1; TOPMed_v3_snplist: 15; Annot_gene: 16; Full dataframe: 16"
# [1] "==========RSQ 0.8; MAF 0001; CADD filtering: "
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 4; TOPMed_v3_snplist: 33; Annot_gene: 37; Full dataframe: 37"
# [1] "==========RSQ 0.8; MAF 0001; CADD filtering: _cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 1; TOPMed_v3_snplist: 14; Annot_gene: 15; Full dataframe: 15"

# %% [markdown]
# ### APOC3 - exome + topmed + hrc

# %%
setwd("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/apoc3")

library(dplyr)
library(genio)
library(data.table)
library(tidyverse)

# %%
for(rsq in c(3, 8)){
    for(maf in c("1", "05", "01")){
        for(cadd in c("", "_cadd")){
            print(sprintf("==========RSQ 0.%d; MAF 00%s; CADD filtering:%s", rsq, maf, cadd))
            
            annot_fname <- sprintf("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/hrc_topmed_exome/hrc_topmed_v3_exome_168206ids_chr11_rsq0%d_maf00%s%s_annot.csv.gz", 
                       rsq, maf, cadd)
            annot_gene <- read.table(annot_fname, sep = ",", header = TRUE) %>% filter(Gene.refGene == "APOC3") %>% unique()
            
            full_df <- read.table("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/id_only.csv", sep = ",", header = TRUE)
            
            exome_fname <- sprintf("APOC3_exome_maf00%s%s_extracted.raw", maf, cadd)
            hrc_fname <- sprintf("APOC3_hrc_rsq0%d_maf00%s%s_extracted.raw", rsq, maf, cadd)
            topmed_fname <- sprintf("APOC3_topmed_v3_rsq0%d_maf00%s%s_extracted.raw", rsq, maf, cadd)

            hrc_snplist <- annot_gene %>% filter(source == "hrc") %>% pull(ID_hg19)
            topmed_snplist <- annot_gene %>% filter(source == "topmed") %>% pull(ID)
            
            ## exome matrix
            if(file.exists(exome_fname)){
                exome <- read.table(exome_fname, sep = "\t", header = TRUE) %>% arrange(FID, IID)
                exome_names <- colnames(exome)[7: dim(exome)[2]] %>% 
                    stringr::str_split(pattern = "_", simplify = TRUE)
                exome_names <- stringr::str_replace_all(exome_names[,1], "\\.", ":")
                colnames(exome)[7:dim(exome)[2]] <- exome_names

                full_df <- left_join(full_df, exome)
            }
            
            ## hrc matrix
            if(file.exists(hrc_fname)){
                hrc <- read.table(hrc_fname, sep = "\t", header = TRUE)
                hrc_names <- colnames(hrc)[7: dim(hrc)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
                hrc_names <- stringr::str_replace_all(hrc_names[,1], "\\.", ":")
                colnames(hrc)[7:dim(hrc)[2]] <- hrc_names

                fid_iid <- hrc$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
                hrc$FID <- as.integer(fid_iid[,1])
                hrc$IID <- as.integer(fid_iid[,2])

                hrc <- hrc %>% arrange(FID, IID) %>% select(c("FID", "IID", "PAT", "MAT", "SEX", "PHENOTYPE", hrc_snplist))
                full_df <- left_join(full_df, hrc)
            }
            
            ## topmed matrix
            if(file.exists(topmed_fname)){
                topmed <- read.table(topmed_fname, sep = "\t", header = TRUE)
                topmed_names <- colnames(topmed)[7: dim(topmed)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
                topmed_names <- stringr::str_replace_all(topmed_names[,1], "\\.", ":")
                colnames(topmed)[7:dim(topmed)[2]] <- topmed_names

                fid_iid <- topmed$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
                topmed$FID <- as.integer(fid_iid[,1])
                topmed$IID <- as.integer(fid_iid[,2])

                topmed <- topmed %>% arrange(FID, IID) %>% select(c("FID", "IID", "PAT", "MAT", "SEX", "PHENOTYPE", topmed_snplist))
                full_df <- left_join(full_df, topmed)
            }
            
            fwrite(full_df, sprintf("APOC3_hrc_topmed_v3_exome_rsq0%d_maf00%s%s_extracted.raw", rsq, maf, cadd))
            
            print(sprintf("HRC_snplist: %d; TOPMed_v3_snplist: %d; Exome: %d; Annot_gene: %d; Full dataframe: %d", 
                          length(hrc_snplist), length(topmed_snplist), ncol(exome)-6, nrow(annot_gene), ncol(full_df)-6))
        }
    }
}
# Out:
# [1] "==========RSQ 0.3; MAF 001; CADD filtering:"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 5; Exome: 60; Annot_gene: 65; Full dataframe: 65"
# [1] "==========RSQ 0.3; MAF 001; CADD filtering:_cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 2; Exome: 26; Annot_gene: 28; Full dataframe: 28"
# [1] "==========RSQ 0.3; MAF 0005; CADD filtering:"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 5; Exome: 60; Annot_gene: 65; Full dataframe: 65"
# [1] "==========RSQ 0.3; MAF 0005; CADD filtering:_cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 2; Exome: 26; Annot_gene: 28; Full dataframe: 28"
# [1] "==========RSQ 0.3; MAF 0001; CADD filtering:"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 5; Exome: 59; Annot_gene: 64; Full dataframe: 64"
# [1] "==========RSQ 0.3; MAF 0001; CADD filtering:_cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 2; Exome: 25; Annot_gene: 27; Full dataframe: 27"
# [1] "==========RSQ 0.8; MAF 001; CADD filtering:"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 0; Exome: 60; Annot_gene: 60; Full dataframe: 60"
# [1] "==========RSQ 0.8; MAF 001; CADD filtering:_cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 0; Exome: 26; Annot_gene: 26; Full dataframe: 26"
# [1] "==========RSQ 0.8; MAF 0005; CADD filtering:"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 0; Exome: 60; Annot_gene: 60; Full dataframe: 60"
# [1] "==========RSQ 0.8; MAF 0005; CADD filtering:_cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 0; Exome: 26; Annot_gene: 26; Full dataframe: 26"
# [1] "==========RSQ 0.8; MAF 0001; CADD filtering:"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 0; Exome: 59; Annot_gene: 59; Full dataframe: 59"
# [1] "==========RSQ 0.8; MAF 0001; CADD filtering:_cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 0; Exome: 25; Annot_gene: 25; Full dataframe: 25"

# %% [markdown]
# ### APOC3 - topmed + hrc

# %%
for(rsq in c(3, 8)){
    for(maf in c("1", "05", "01")){
        for(cadd in c("", "_cadd")){
            print(sprintf("==========RSQ 0.%d; MAF 00%s; CADD filtering: %s", rsq, maf, cadd))
            annot_fname <- sprintf("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/hrc_topmed/hrc_topmed_v3_168206ids_chr11_rsq0%d_maf00%s%s_annot.csv.gz", 
                                   rsq, maf, cadd)
            annot_gene <- read.table(annot_fname, sep = ",", header = TRUE) %>% filter(Gene.refGene == "APOC3") %>% unique()
            
            full_df <- read.table("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/id_only.csv", sep = ",", header = TRUE)
            
            hrc_fname <- sprintf("APOC3_hrc_rsq0%d_maf00%s%s_extracted.raw", rsq, maf, cadd)
            topmed_fname <- sprintf("APOC3_topmed_v3_rsq0%d_maf00%s%s_extracted.raw", rsq, maf, cadd)
            
            hrc_snplist <- annot_gene %>% filter(source == "hrc") %>% pull(ID_hg19)
            topmed_snplist <- annot_gene %>% filter(source == "topmed") %>% pull(ID)

            ## hrc matrix
            if(file.exists(hrc_fname)){
                hrc <- read.table(hrc_fname, sep = "\t", header = TRUE)
                hrc_names <- colnames(hrc)[7: dim(hrc)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
                hrc_names <- stringr::str_replace_all(hrc_names[,1], "\\.", ":")
                colnames(hrc)[7:dim(hrc)[2]] <- hrc_names

                fid_iid <- hrc$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
                hrc$FID <- as.integer(fid_iid[,1])
                hrc$IID <- as.integer(fid_iid[,2])

                hrc <- hrc %>% arrange(FID, IID) %>% select(c("FID", "IID", "PAT", "MAT", "SEX", "PHENOTYPE", hrc_snplist))
                full_df <- left_join(full_df, hrc)
            }
            
            ## topmed matrix
            if(file.exists(topmed_fname)){
                topmed <- read.table(topmed_fname, sep = "\t", header = TRUE)
                topmed_names <- colnames(topmed)[7: dim(topmed)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
                topmed_names <- stringr::str_replace_all(topmed_names[,1], "\\.", ":")
                colnames(topmed)[7:dim(topmed)[2]] <- topmed_names

                fid_iid <- topmed$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
                topmed$FID <- as.integer(fid_iid[,1])
                topmed$IID <- as.integer(fid_iid[,2])

                topmed <- topmed %>% arrange(FID, IID) %>% select(c("FID", "IID", "PAT", "MAT", "SEX", "PHENOTYPE", topmed_snplist))
                full_df <- left_join(full_df, topmed)
            }
            
            fwrite(full_df, sprintf("APOC3_hrc_topmed_v3_rsq0%d_maf00%s%s_extracted.raw", rsq, maf, cadd))
            
            print(sprintf("HRC_snplist: %d; TOPMed_v3_snplist: %d; Annot_gene: %d; Full dataframe: %d", 
                          length(hrc_snplist), length(topmed_snplist), nrow(annot_gene), ncol(full_df)-6))
        }
    }
}
# Out:
# [1] "==========RSQ 0.3; MAF 001; CADD filtering: "
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 2; TOPMed_v3_snplist: 16; Annot_gene: 18; Full dataframe: 18"
# [1] "==========RSQ 0.3; MAF 001; CADD filtering: _cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 2; TOPMed_v3_snplist: 8; Annot_gene: 10; Full dataframe: 10"
# [1] "==========RSQ 0.3; MAF 0005; CADD filtering: "
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 2; TOPMed_v3_snplist: 16; Annot_gene: 18; Full dataframe: 18"
# [1] "==========RSQ 0.3; MAF 0005; CADD filtering: _cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 2; TOPMed_v3_snplist: 8; Annot_gene: 10; Full dataframe: 10"
# [1] "==========RSQ 0.3; MAF 0001; CADD filtering: "
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 2; TOPMed_v3_snplist: 15; Annot_gene: 17; Full dataframe: 17"
# [1] "==========RSQ 0.3; MAF 0001; CADD filtering: _cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 2; TOPMed_v3_snplist: 7; Annot_gene: 9; Full dataframe: 9"
# [1] "==========RSQ 0.8; MAF 001; CADD filtering: "
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 1; TOPMed_v3_snplist: 3; Annot_gene: 4; Full dataframe: 4"
# [1] "==========RSQ 0.8; MAF 001; CADD filtering: _cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 1; TOPMed_v3_snplist: 3; Annot_gene: 4; Full dataframe: 4"
# [1] "==========RSQ 0.8; MAF 0005; CADD filtering: "
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 1; TOPMed_v3_snplist: 3; Annot_gene: 4; Full dataframe: 4"
# [1] "==========RSQ 0.8; MAF 0005; CADD filtering: _cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 1; TOPMed_v3_snplist: 3; Annot_gene: 4; Full dataframe: 4"
# [1] "==========RSQ 0.8; MAF 0001; CADD filtering: "
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 3; Annot_gene: 3; Full dataframe: 3"
# [1] "==========RSQ 0.8; MAF 0001; CADD filtering: _cadd"
# Joining with `by = join_by(FID, IID, PAT, MAT, SEX, PHENOTYPE)`
# [1] "HRC_snplist: 0; TOPMed_v3_snplist: 3; Annot_gene: 3; Full dataframe: 3"

# %% [markdown]
# ## Phenotype Analysis

# %% [markdown]
# We are going to be using Burden of Rare Variant ([BRV](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4459641/)) to analyze rare variant aggregate association for PCSK9 and APOC3. For phenotype analysis, we control for age, sex and 2 PC's.

# %% [markdown]
# ### Functions and Packages

# %%
library(dplyr)
library(genio)
library(data.table)
library(tidyverse)

# %%
# mi_pheno <- read.csv("/home/tl3031/project/imputation-rvtest/analysis/imputation_aggregated_analysis/Unrealted_White_EU_Both_Exo_Impu_5209_MI_cases.phe.csv")
# mi_y <- mi_pheno %>% arrange(FID) %>% pull(MI)

###########################################
# trig_ldl_pheno <- read.csv("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/Trigly_LDL_Log10_168206ind.phe.csv") %>% arrange(FID)
# tg_y <- trig_ldl_pheno %>% arrange(FID) %>% pull(logarithm_base10_Trigli)
# ldl_y <- trig_ldl_pheno  %>% arrange(FID) %>% pull(f.30780.0.0)

###########################################
ldl_df <- read.csv("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/UKBB_LDL_159759inds_4PCs.pheno", sep = "\t") %>% arrange(FID)
ldl_y <- ldl_df %>% pull(f.30780.0.0)
ldl_id <- ldl_df %>% pull(IID)
ldl_cov <- ldl_df %>% select(sex, age, PC1, PC2)

tg_df <- read.csv("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/UKBB_TG_159759inds_4PCs.pheno", sep = "\t") %>% arrange(FID)
tg_y <- tg_df %>% pull(logarithm_base10_Trigli)
tg_id <- tg_df %>% pull(IID)
tg_cov <- tg_df %>% select(sex, age, PC1, PC2)

rm(ldl_df, tg_df)

# %%
# the BRV function
BRV <- function(X_mat, y, cov, option = "binomial"){
    X_mat <- as.matrix(X_mat)
    y <- as.vector(y)

    ## cout number of rare variants for each individual
    if(ncol(X_mat) == 1){
        X_mat_new = X_mat
    } else {
        X_mat_new  = rowSums(X_mat, na.rm=TRUE) %>% as.matrix()
    }
    
    age <- cov$age
    sex <- cov$sex
    pc1 <- cov$PC1
    pc2 <- cov$PC2

    ## obtain p value by logistic regression
    mat.fit <- glm(y ~ X_mat_new + age + sex + pc1 + pc2, family = option)
    zstat <- coef(summary(mat.fit))[2, 3]
    pval <- coef(summary(mat.fit))[2, 4]

    return(list(zstat = zstat, pval = pval))
}

# %% [markdown]
# ### PCSK9 v.s. LDL

# %%
setwd('/mnt/vast/hpc/csg/tl3031/imputation-rvtest/analysis/imputation_aggregated_analysis/pcsk9')

# %%
result_df <- data.frame(data.frame(matrix(ncol = 5, nrow = 0)))
colnames(result_df) <- c("data", "rsqs", "mafs", "num_var", "pvals")

for(maf in c("1", "05", "01")){
    exome_fname <- sprintf("PCSK9_exome_maf00%s_extracted.raw", maf)
    if(file.exists(exome_fname)){
        exome <- read.table(exome_fname, sep = "\t", header = TRUE) %>% arrange(FID, IID)
        exome_X <- exome %>% arrange(FID, IID) %>% filter(FID %in% ldl_id) %>% select(-c(1:6)) %>% as.matrix()
        result_exome <- BRV(2 - exome_X, ldl_y, ldl_cov,"gaussian")
    } else {
        exome_X <- matrix()
        result_exome$pval <- NA
    }

    for(rsq in c(3, 8)){
        hrc_fname <- sprintf("PCSK9_hrc_rsq0%d_maf00%s_extracted.raw", rsq, maf)
        topmed_fname <- sprintf("PCSK9_topmed_v3_rsq0%d_maf00%s_extracted.raw", rsq, maf)
        hrc_topmed_fname <- sprintf("PCSK9_hrc_topmed_v3_rsq0%d_maf00%s_extracted.raw", rsq, maf)
        hrc_topmed_exome_fname <- sprintf("PCSK9_hrc_topmed_v3_exome_rsq0%d_maf00%s_extracted.raw", rsq, maf)

        if(file.exists(hrc_fname)){
            hrc <- read.table(hrc_fname, sep = "\t", header = TRUE)
            
            fid_iid <- hrc$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
            hrc$FID <- as.integer(fid_iid[,1])
            hrc$IID <- as.integer(fid_iid[,2])
            hrc_X <- hrc %>% arrange(FID, IID) %>% filter(FID %in% ldl_id) %>% select(-c(1:6)) %>% as.matrix()

            result_hrc <- BRV(2 - hrc_X, ldl_y, ldl_cov, "gaussian")

        } else {
            hrc_X <- matrix()
            result_hrc$pval <- NA
        }
        
        if(file.exists(topmed_fname)){
            topmed <- read.table(topmed_fname, sep = "\t", header = TRUE)
            
            fid_iid <- topmed$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
            topmed$FID <- as.integer(fid_iid[,1])
            topmed$IID <- as.integer(fid_iid[,2])

            topmed_X <- topmed %>% arrange(FID, IID) %>% filter(FID %in% ldl_id) %>% select(-c(1:6)) %>% as.matrix()
            result_topmed <- BRV(2 - topmed_X, ldl_y, ldl_cov, "gaussian")
        } else {
            topmed_X <- matrix()
            result_topmed$pval <- NA
        }

        if(file.exists(hrc_topmed_fname)){
            hrc_topmed <- read.table(hrc_topmed_fname, sep = ",", header = TRUE)
            hrc_topmed_X <- hrc_topmed %>% arrange(FID, IID) %>% filter(FID %in% ldl_id) %>% select(-c(1:6)) %>% as.matrix()
            result_hrc_topmed <- BRV(2 - hrc_topmed_X, ldl_y, ldl_cov, "gaussian")
        } else {
            hrc_topmed_X <- matrix()
            result_hrc_topmed$pval <- NA
        }

        if(file.exists(hrc_topmed_exome_fname)){
            hrc_topmed_exome <- read.table(hrc_topmed_exome_fname, sep = ",", header = TRUE)
            hrc_topmed_exome_X <- hrc_topmed_exome %>% arrange(FID, IID) %>% filter(FID %in% ldl_id) %>% select(-c(1:6)) %>% as.matrix()
            result_hrc_topmed_exome <- BRV(2 - hrc_topmed_exome_X, ldl_y, ldl_cov, "gaussian")
        } else {
            hrc_topmed_exome_X <- matrix()
            result_hrc_topmed_exome$pval <- NA
        }

        data <- c("hrc", "topmed", "hrc_topmed", "hrc_topmed_exome")
        rsqs <- rep(rsq/10, 4)
        mafs <- rep(paste0("0.0", maf), 4)
        pvals <- c(result_hrc$pval, result_topmed$pval, result_hrc_topmed$pval, result_hrc_topmed_exome$pval)
        num_var <- c(ncol(hrc_X), ncol(topmed_X), ncol(hrc_topmed_X), ncol(hrc_topmed_exome_X))
        sub_df <- data.frame(data, rsqs, mafs, num_var, pvals)
        result_df <- rbind(result_df, sub_df)
    }
    result_df <- rbind(data.frame(data = "exome", rsqs = "NA", mafs = paste0("0.0", maf), num_var = ncol(exome_X), pvals = result_exome$pval), result_df)
}

# %%
result_df %>% 
    mutate(data = factor(data, levels = c("exome", "hrc", "topmed", "hrc_topmed", "hrc_topmed_exome"))) %>% 
    arrange(desc(as.numeric(mafs)), data)
# Out:
#    data             rsqs mafs  num_var pvals
# 1  exome            NA   0.01  394     5.473985e-71
# 2  hrc              0.3  0.01   16     1.944983e-12
# 3  hrc              0.8  0.01    6     6.993942e-11
# 4  topmed           0.3  0.01  124     2.403941e-38
# 5  topmed           0.8  0.01   34     7.399230e-30
# 6  hrc_topmed       0.3  0.01  125     1.146106e-39
# 7  hrc_topmed       0.8  0.01   38     5.148051e-32
# 8  hrc_topmed_exome 0.3  0.01  412     8.865311e-71
# 9  hrc_topmed_exome 0.8  0.01  394     5.473985e-71
# 10 exome            NA   0.005 394     5.473985e-71
# 11 hrc              0.3  0.005  16     1.944983e-12
# 12 hrc              0.8  0.005   6     6.993942e-11
# 13 topmed           0.3  0.005 124     2.403941e-38
# 14 topmed           0.8  0.005  34     7.399230e-30
# 15 hrc_topmed       0.3  0.005 125     1.146106e-39
# 16 hrc_topmed       0.8  0.005  38     5.148051e-32
# 17 hrc_topmed_exome 0.3  0.005 412     8.865311e-71
# 18 hrc_topmed_exome 0.8  0.005 394     5.473985e-71
# 19 exome            NA   0.001 393     9.347929e-53
# 20 hrc              0.3  0.001  15     2.387199e-09
# 21 hrc              0.8  0.001   6     6.993942e-11
# 22 topmed           0.3  0.001 123     5.232206e-26
# 23 topmed           0.8  0.001  33     5.721054e-17
# 24 hrc_topmed       0.3  0.001 124     4.189196e-27
# 25 hrc_topmed       0.8  0.001  37     3.530685e-19
# 26 hrc_topmed_exome 0.3  0.001 411     1.368744e-52
# 27 hrc_topmed_exome 0.8  0.001 393     9.347929e-53

# %%
result_df <- data.frame(data.frame(matrix(ncol = 5, nrow = 0)))
colnames(result_df) <- c("data", "rsqs", "mafs", "num_var", "pvals")

for(maf in c("1", "05", "01")){
    exome_fname <- sprintf("PCSK9_exome_maf00%s_cadd_extracted.raw", maf)
    if(file.exists(exome_fname)){
        exome <- read.table(exome_fname, sep = "\t", header = TRUE) %>% arrange(FID, IID)
        exome_X <- exome %>% arrange(FID, IID) %>% filter(FID %in% ldl_id) %>% select(-c(1:6)) %>% as.matrix()
        result_exome <- BRV(2 - exome_X, ldl_y, ldl_cov, "gaussian")
    } else {
        exome_X <- matrix()
        result_exome$pval <- NA
    }

    for(rsq in c(3, 8)){
        hrc_fname <- sprintf("PCSK9_hrc_rsq0%d_maf00%s_cadd_extracted.raw", rsq, maf)
        topmed_fname <- sprintf("PCSK9_topmed_v3_rsq0%d_maf00%s_cadd_extracted.raw", rsq, maf)
        hrc_topmed_fname <- sprintf("PCSK9_hrc_topmed_v3_rsq0%d_maf00%s_cadd_extracted.raw", rsq, maf)
        hrc_topmed_exome_fname <- sprintf("PCSK9_hrc_topmed_v3_exome_rsq0%d_maf00%s_cadd_extracted.raw", rsq, maf)

        if(file.exists(hrc_fname)){
            hrc <- read.table(hrc_fname, sep = "\t", header = TRUE)
            
            fid_iid <- hrc$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
            hrc$FID <- as.integer(fid_iid[,1])
            hrc$IID <- as.integer(fid_iid[,2])
            hrc_X <- hrc %>% arrange(FID, IID) %>% filter(FID %in% ldl_id) %>% select(-c(1:6)) %>% as.matrix()

            result_hrc <- BRV(2 - hrc_X, ldl_y, ldl_cov,"gaussian")

        } else {
            hrc_X <- matrix()
            result_hrc$pval <- NA
        }
        
        if(file.exists(topmed_fname)){
            topmed <- read.table(topmed_fname, sep = "\t", header = TRUE)
            
            fid_iid <- topmed$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
            topmed$FID <- as.integer(fid_iid[,1])
            topmed$IID <- as.integer(fid_iid[,2])

            topmed_X <- topmed %>% arrange(FID, IID) %>% filter(FID %in% ldl_id) %>% select(-c(1:6)) %>% as.matrix()
            result_topmed <- BRV(2 - topmed_X, ldl_y, ldl_cov,"gaussian")
        } else {
            topmed_X <- matrix()
            result_topmed$pval <- NA
        }

        if(file.exists(hrc_topmed_fname)){
            hrc_topmed <- read.table(hrc_topmed_fname, sep = ",", header = TRUE)
            hrc_topmed_X <- hrc_topmed %>% arrange(FID, IID) %>% filter(FID %in% ldl_id) %>% select(-c(1:6)) %>% as.matrix()
            result_hrc_topmed <- BRV(2 - hrc_topmed_X, ldl_y, ldl_cov,"gaussian")
        } else {
            hrc_topmed_X <- matrix()
            result_hrc_topmed$pval <- NA
        }

        if(file.exists(hrc_topmed_exome_fname)){
            hrc_topmed_exome <- read.table(hrc_topmed_exome_fname, sep = ",", header = TRUE)
            hrc_topmed_exome_X <- hrc_topmed_exome %>% arrange(FID, IID) %>% filter(FID %in% ldl_id) %>% select(-c(1:6)) %>% as.matrix()
            result_hrc_topmed_exome <- BRV(2 - hrc_topmed_exome_X, ldl_y, ldl_cov,"gaussian")
        } else {
            hrc_topmed_exome_X <- matrix()
            result_hrc_topmed_exome$pval <- NA
        }

        data <- c("hrc", "topmed", "hrc_topmed", "hrc_topmed_exome")
        rsqs <- rep(rsq/10, 4)
        mafs <- rep(paste0("0.0", maf), 4)
        pvals <- c(result_hrc$pval, result_topmed$pval, result_hrc_topmed$pval, result_hrc_topmed_exome$pval)
        num_var <- c(ncol(hrc_X), ncol(topmed_X), ncol(hrc_topmed_X), ncol(hrc_topmed_exome_X))
        sub_df <- data.frame(data, rsqs, mafs, num_var, pvals)
        result_df <- rbind(result_df, sub_df)
    }
    result_df <- rbind(data.frame(data = "exome", rsqs = "NA", mafs = paste0("0.0", maf), num_var = ncol(exome_X), pvals = result_exome$pval), result_df)
}

# %%
result_df %>% 
    mutate(data = factor(data, levels = c("exome", "hrc", "topmed", "hrc_topmed", "hrc_topmed_exome"))) %>% 
    arrange(desc(as.numeric(mafs)), data)
# Out:
#    data             rsqs mafs  num_var pvals
# 1  exome            NA   0.01  200     8.246876e-93
# 2  hrc              0.3  0.01    6     1.912681e-12
# 3  hrc              0.8  0.01    2     4.563676e-15
# 4  topmed           0.3  0.01   61     1.287643e-54
# 5  topmed           0.8  0.01   15     1.227744e-44
# 6  hrc_topmed       0.3  0.01   61     3.754704e-54
# 7  hrc_topmed       0.8  0.01   16     3.683660e-45
# 8  hrc_topmed_exome 0.3  0.01  204     2.554497e-93
# 9  hrc_topmed_exome 0.8  0.01  200     8.246876e-93
# 10 exome            NA   0.005 200     8.246876e-93
# 11 hrc              0.3  0.005   6     1.912681e-12
# 12 hrc              0.8  0.005   2     4.563676e-15
# 13 topmed           0.3  0.005  61     1.287643e-54
# 14 topmed           0.8  0.005  15     1.227744e-44
# 15 hrc_topmed       0.3  0.005  61     3.754704e-54
# 16 hrc_topmed       0.8  0.005  16     3.683660e-45
# 17 hrc_topmed_exome 0.3  0.005 204     2.554497e-93
# 18 hrc_topmed_exome 0.8  0.005 200     8.246876e-93
# 19 exome            NA   0.001 199     2.525363e-74
# 20 hrc              0.3  0.001   5     5.727402e-12
# 21 hrc              0.8  0.001   2     4.563676e-15
# 22 topmed           0.3  0.001  60     9.894265e-42
# 23 topmed           0.8  0.001  14     3.983099e-34
# 24 hrc_topmed       0.3  0.001  60     3.143422e-41
# 25 hrc_topmed       0.8  0.001  15     1.152055e-34
# 26 hrc_topmed_exome 0.3  0.001 203     7.679194e-75
# 27 hrc_topmed_exome 0.8  0.001 199     2.525363e-74

# %% [markdown]
# #### PCSK9: chr1:55052701:C:T (hg38)

# %%
# pcsk9_id_maf001 <- read.csv("PCSK9_exome_maf001_annot.csv.gz")$ID_hg38
# pcsk9_id_maf0001 <- read.csv("PCSK9_exome_maf0001_annot.csv.gz")$ID_hg38
# setdiff(pcsk9_id_maf001, pcsk9_id_maf0001)

# read.csv("PCSK9_exome_maf001_annot.csv.gz") %>% filter(ID_hg38 == 'chr1:55052701:C:T')

# %% [markdown]
# We are interested in this variant, because we see that after removal, the p-value has increased a lot. Therefore, we are going to conduct a single varaint association testing for this variants alone using exome and imputed data.

# %%
# ## exome data
# exome_bim <- read_bim("PCSK9_exome_maf001_extracted.bim")
# exome_fam <- read_fam("PCSK9_exome_maf001_extracted.fam")
# exome <- read_bed("PCSK9_exome_maf001_extracted.bed", exome_bim$id, exome_fam$id)

# exome_X <- data.frame(ID = names(exome["chr1:55052701:C:T",]), value=exome["chr1:55052701:C:T",], row.names=NULL)
# exome_X <- exome_X %>% arrange(as.numeric(ID)) %>% filter(ID %in% ldl_id) %>% select(-ID) %>% as.matrix()

# exome.fit <- glm(ldl_y ~ exome_X + ldl_cov$age + ldl_cov$sex + ldl_cov$PC1 + ldl_cov$PC2, family = "gaussian")
# coef(summary(exome.fit))[2, 4]

# %%
# read.csv("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/hrc_topmed/hrc_topmed_v3_168206ids_rsq03_maf001_annot.csv.gz") %>%
#     filter(ID_hg38 == "chr1:55052701:C:T")

# ## hrc
# hrc <- read.csv("PCSK9_hrc_rsq03_maf001_extracted.traw") %>% filter(SNP == "chr1:55518374:C:T")
# hrc_X <- format_traw(hrc, ldl_id, "hrc")

# hrc.fit <- glm(ldl_y ~ hrc_X + ldl_cov$age + ldl_cov$sex + ldl_cov$PC1 + ldl_cov$PC2, family = "gaussian")
# coef(summary(hrc.fit))[2, 4]

# ## topmed
# topmed <- read.csv("PCSK9_topmed_rsq03_maf001_extracted.traw") %>% filter(SNP == "chr1:55052701:C:T")
# topmed_X <- format_traw(topmed, ldl_id, "topmed")

# topmed.fit <- glm(ldl_y ~ topmed_X + ldl_cov$age + ldl_cov$sex + ldl_cov$PC1 + ldl_cov$PC2, family = "gaussian")
# coef(summary(topmed.fit))[2, 4]

# %% [markdown]
# ### APOC3 v.s. TG

# %%
setwd('/mnt/vast/hpc/csg/tl3031/imputation-rvtest/analysis/imputation_aggregated_analysis/apoc3')

result_df <- data.frame(data.frame(matrix(ncol = 5, nrow = 0)))
colnames(result_df) <- c("data", "rsqs", "mafs", "num_var", "pvals")

for(maf in c("1", "05", "01")){
    exome_fname <- sprintf("APOC3_exome_maf00%s_extracted.raw", maf)
    if(file.exists(exome_fname)){
        exome <- read.table(exome_fname, sep = "\t", header = TRUE)
        exome_X <- exome %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()
        result_exome <- BRV(2 - exome_X, tg_y, tg_cov,"gaussian")
    } else {
        exome_X <- matrix()
        result_exome$pval <- NA
    }

    for(rsq in c(3, 8)){
        hrc_fname <- sprintf("APOC3_hrc_rsq0%d_maf00%s_extracted.raw", rsq, maf)
        topmed_fname <- sprintf("APOC3_topmed_v3_rsq0%d_maf00%s_extracted.raw", rsq, maf)
        hrc_topmed_fname <- sprintf("APOC3_hrc_topmed_v3_rsq0%d_maf00%s_extracted.raw", rsq, maf)
        hrc_topmed_exome_fname <- sprintf("APOC3_hrc_topmed_v3_exome_rsq0%d_maf00%s_extracted.raw", rsq, maf)

        if(file.exists(hrc_fname)){
            hrc <- read.table(hrc_fname, sep = "\t", header = TRUE)
            
            fid_iid <- hrc$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
            hrc$FID <- as.integer(fid_iid[,1])
            hrc$IID <- as.integer(fid_iid[,2])
            hrc_X <- hrc %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()

            result_hrc <- BRV(2 - hrc_X, tg_y, tg_cov,"gaussian")

        } else {
            hrc_X <- matrix()
            result_hrc$pval <- NA
        }
        
        if(file.exists(topmed_fname)){
            topmed <- read.table(topmed_fname, sep = "\t", header = TRUE)
            
            fid_iid <- topmed$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
            topmed$FID <- as.integer(fid_iid[,1])
            topmed$IID <- as.integer(fid_iid[,2])

            topmed_X <- topmed %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()
            result_topmed <- BRV(2 - topmed_X, tg_y, tg_cov,"gaussian")
        } else {
            topmed_X <- matrix()
            result_topmed$pval <- NA
        }

        if(file.exists(hrc_topmed_fname)){
            hrc_topmed <- read.table(hrc_topmed_fname, sep = ",", header = TRUE)
            hrc_topmed_X <- hrc_topmed %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()
            result_hrc_topmed <- BRV(2 - hrc_topmed_X, tg_y, tg_cov,"gaussian")
        } else {
            hrc_topmed_X <- matrix()
            result_hrc_topmed$pval <- NA
        }

        if(file.exists(hrc_topmed_exome_fname)){
            hrc_topmed_exome <- read.csv(hrc_topmed_exome_fname, sep = ",", header = TRUE)
            hrc_topmed_exome_X <- hrc_topmed_exome %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()
            result_hrc_topmed_exome <- BRV(2 - hrc_topmed_exome_X, tg_y, tg_cov,"gaussian")
        } else {
            hrc_topmed_exome_X <- matrix()
            result_hrc_topmed_exome$pval <- NA
        }

        data <- c("hrc", "topmed", "hrc_topmed", "hrc_topmed_exome")
        rsqs <- rep(rsq/10, 4)
        mafs <- rep(paste0("0.0", maf), 4)
        pvals <- c(result_hrc$pval, result_topmed$pval, result_hrc_topmed$pval, result_hrc_topmed_exome$pval)
        num_var <- c(ncol(hrc_X), ncol(topmed_X), ncol(hrc_topmed_X), ncol(hrc_topmed_exome_X))
        sub_df <- data.frame(data, rsqs, mafs, num_var, pvals)
        result_df <- rbind(result_df, sub_df)
    }
    result_df <- rbind(data.frame(data = "exome", rsqs = "NA", mafs = paste0("0.0", maf), num_var = ncol(exome_X), pvals = result_exome$pval), result_df)
}

# %%
result_df %>% 
    mutate(data = factor(data, levels = c("exome", "hrc", "topmed", "hrc_topmed", "hrc_topmed_exome"))) %>% 
    arrange(desc(as.numeric(mafs)), data)
# Out:
#    data             rsqs mafs  num_var pvals
# 1  exome            NA   0.01  60      3.073400e-234
# 2  hrc              0.3  0.01   3      3.376964e-182
# 3  hrc              0.8  0.01   2      9.967896e-170
# 4  topmed           0.3  0.01  18      1.342452e-190
# 5  topmed           0.8  0.01   4      1.761751e-183
# 6  hrc_topmed       0.3  0.01  18      4.145103e-187
# 7  hrc_topmed       0.8  0.01   4      6.413400e-183
# 8  hrc_topmed_exome 0.3  0.01  65      3.666208e-231
# 9  hrc_topmed_exome 0.8  0.01  60      3.073400e-234
# 10 exome            NA   0.005 60      3.073400e-234
# 11 hrc              0.3  0.005  3      3.376964e-182
# 12 hrc              0.8  0.005  2      9.967896e-170
# 13 topmed           0.3  0.005 18      1.342452e-190
# 14 topmed           0.8  0.005  4      1.761751e-183
# 15 hrc_topmed       0.3  0.005 18      4.145103e-187
# 16 hrc_topmed       0.8  0.005  4      6.413400e-183
# 17 hrc_topmed_exome 0.3  0.005 65      3.666208e-231
# 18 hrc_topmed_exome 0.8  0.005 60      3.073400e-234
# 19 exome            NA   0.001 59       5.468090e-32
# 20 hrc              0.3  0.001  2       3.385530e-24
# 21 hrc              0.8  0.001  1                 NA
# 22 topmed           0.3  0.001 17       1.393809e-25
# 23 topmed           0.8  0.001  3       1.488747e-13
# 24 hrc_topmed       0.3  0.001 17       2.634573e-20
# 25 hrc_topmed       0.8  0.001  3       1.488747e-13
# 26 hrc_topmed_exome 0.3  0.001 64       1.188269e-30
# 27 hrc_topmed_exome 0.8  0.001 59       5.468090e-32

# %%
result_df <- data.frame(data.frame(matrix(ncol = 5, nrow = 0)))
colnames(result_df) <- c("data", "rsqs", "mafs", "num_var", "pvals")

for(maf in c("1", "05", "01")){
    exome_fname <- sprintf("APOC3_exome_maf00%s_cadd_extracted.raw", maf)
    if(file.exists(exome_fname)){
        exome <- read.table(exome_fname, sep = "\t", header = TRUE)
        exome_X <- exome %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()
        result_exome <- BRV(2 - exome_X, tg_y, tg_cov,"gaussian")
    } else {
        exome_X <- matrix()
        result_exome$pval <- NA
    }

    for(rsq in c(3, 8)){
        hrc_fname <- sprintf("APOC3_hrc_rsq0%d_maf00%s_cadd_extracted.raw", rsq, maf)
        topmed_fname <- sprintf("APOC3_topmed_v3_rsq0%d_maf00%s_cadd_extracted.raw", rsq, maf)
        hrc_topmed_fname <- sprintf("APOC3_hrc_topmed_v3_rsq0%d_maf00%s_cadd_extracted.raw", rsq, maf)
        hrc_topmed_exome_fname <- sprintf("APOC3_hrc_topmed_v3_exome_rsq0%d_maf00%s_cadd_extracted.raw", rsq, maf)

        if(file.exists(hrc_fname)){
            hrc <- read.table(hrc_fname, sep = "\t", header = TRUE)
            hrc_names <- colnames(hrc)[7: dim(hrc)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
            colnames(hrc)[7:dim(hrc)[2]] <- hrc_names[,1]

            fid_iid <- hrc$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
            hrc$FID <- as.integer(fid_iid[,1])
            hrc$IID <- as.integer(fid_iid[,2])
            hrc_X <- hrc %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()

            result_hrc <- BRV(2 - hrc_X, tg_y, tg_cov,"gaussian")

        } else {
            hrc_X <- matrix()
            result_hrc$pval <- NA
        }
        
        if(file.exists(topmed_fname)){
            topmed <- read.csv(topmed_fname, sep = "\t", header = TRUE)
            topmed_names <- colnames(topmed)[7: dim(topmed)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
            colnames(topmed)[7:dim(topmed)[2]] <- topmed_names[,1]

            fid_iid <- topmed$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
            topmed$FID <- as.integer(fid_iid[,1])
            topmed$IID <- as.integer(fid_iid[,2])

            topmed_X <- topmed %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()
            result_topmed <- BRV(2 - topmed_X, tg_y, tg_cov,"gaussian")
        } else {
            topmed_X <- matrix()
            result_topmed$pval <- NA
        }

        if(file.exists(hrc_topmed_fname)){
            hrc_topmed <- read.table(hrc_topmed_fname, sep = ",", header = TRUE)
            hrc_topmed_X <- hrc_topmed %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()
            result_hrc_topmed <- BRV(2 - hrc_topmed_X, tg_y, tg_cov,"gaussian")
        } else {
            hrc_topmed_X <- matrix()
            result_hrc_topmed$pval <- NA
        }

        if(file.exists(hrc_topmed_exome_fname)){
            hrc_topmed_exome <- read.table(hrc_topmed_exome_fname, sep = ",", header = TRUE)
            hrc_topmed_exome_X <- hrc_topmed_exome %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()
            result_hrc_topmed_exome <- BRV(2 - hrc_topmed_exome_X, tg_y, tg_cov,"gaussian")
        } else {
            hrc_topmed_exome_X <- matrix()
            result_hrc_topmed_exome$pval <- NA
        }

        data <- c("hrc", "topmed", "hrc_topmed", "hrc_topmed_exome")
        rsqs <- rep(rsq/10, 4)
        mafs <- rep(paste0("0.0", maf), 4)
        pvals <- c(result_hrc$pval, result_topmed$pval, result_hrc_topmed$pval, result_hrc_topmed_exome$pval)
        num_var <- c(ncol(hrc_X), ncol(topmed_X), ncol(hrc_topmed_X), ncol(hrc_topmed_exome_X))
        sub_df <- data.frame(data, rsqs, mafs, num_var, pvals)
        result_df <- rbind(result_df, sub_df)
    }
    result_df <- rbind(data.frame(data = "exome", rsqs = "NA", mafs = paste0("0.0", maf), num_var = ncol(exome_X), pvals = result_exome$pval), result_df)
}

# %%
result_df %>% 
    mutate(data = factor(data, levels = c("exome", "hrc", "topmed", "hrc_topmed", "hrc_topmed_exome"))) %>% 
    arrange(desc(as.numeric(mafs)), data)
# Out:
#    data             rsqs mafs  num_var pvals
# 1  exome            NA   0.01  26      1.050377e-262
# 2  hrc              0.3  0.01   3      3.376964e-182
# 3  hrc              0.8  0.01   2      9.967896e-170
# 4  topmed           0.3  0.01  10      4.038258e-197
# 5  topmed           0.8  0.01   4      1.761751e-183
# 6  hrc_topmed       0.3  0.01  10      4.597154e-194
# 7  hrc_topmed       0.8  0.01   4      6.413400e-183
# 8  hrc_topmed_exome 0.3  0.01  28      8.537625e-260
# 9  hrc_topmed_exome 0.8  0.01  26      1.050377e-262
# 10 exome            NA   0.005 26      1.050377e-262
# 11 hrc              0.3  0.005  3      3.376964e-182
# 12 hrc              0.8  0.005  2      9.967896e-170
# 13 topmed           0.3  0.005 10      4.038258e-197
# 14 topmed           0.8  0.005  4      1.761751e-183
# 15 hrc_topmed       0.3  0.005 10      4.597154e-194
# 16 hrc_topmed       0.8  0.005  4      6.413400e-183
# 17 hrc_topmed_exome 0.3  0.005 28      8.537625e-260
# 18 hrc_topmed_exome 0.8  0.005 26      1.050377e-262
# 19 exome            NA   0.001 25       9.616993e-48
# 20 hrc              0.3  0.001  2       3.385530e-24
# 21 hrc              0.8  0.001  1                 NA
# 22 topmed           0.3  0.001  9       2.254842e-28
# 23 topmed           0.8  0.001  3       1.488747e-13
# 24 hrc_topmed       0.3  0.001  9       2.233109e-23
# 25 hrc_topmed       0.8  0.001  3       1.488747e-13
# 26 hrc_topmed_exome 0.3  0.001 27       1.482569e-45
# 27 hrc_topmed_exome 0.8  0.001 25       9.616993e-48

# %% [markdown]
# #### APOC3: chr11:116830638
#
# We specifically looked into this variant, for the same reason we did for the PCSK9 variant

# %%
annot_001 <- read.csv("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/hrc_topmed_exome/hrc_topmed_v3_exome_168206ids_chr11_rsq03_maf001_annot.csv.gz") %>%
    filter(Gene.refGene == "APOC3") %>% pull(ID)
annot_0001 <- read.csv("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/hrc_topmed_exome/hrc_topmed_v3_exome_168206ids_chr11_rsq03_maf0001_annot.csv.gz")  %>%
    filter(Gene.refGene == "APOC3") %>% pull(ID)

setdiff(annot_001, annot_0001)

read.csv("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/hrc_topmed_exome/hrc_topmed_v3_exome_168206ids_chr11_rsq03_maf001_annot.csv.gz") %>%
    filter(ID == 'chr11:116830638:G:A') %>% select(c(1:7, R2_hrc, R2_topmed))
# Out:
# [1] "chr11:116830638:G:A"
#   Chr Start     End       Ref Alt ID_hg38             ID_hg19
# 1 11  116830638 116830638 G   A   chr11:116830638:G:A chr11:116701354:G:A
#   R2_hrc   R2_topmed
# 1 0.836202 0.853641

# %%
exome <- read.csv("APOC3_exome_maf001_extracted.raw")
exome_names <- colnames(exome)[7: dim(exome)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
colnames(exome)[7:dim(exome)[2]] <- exome_names[,1]

exome_X <- exome %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()

result_exome <- BRV(2 - exome_X[,'chr11:116830638:G:A'], tg_y, tg_cov,"gaussian")
result_exome
# Out:
# $zstat
# [1] -31.65787
#
# $pval
# [1] 2.8363e-219

# %%
hrc <- read.csv("APOC3_hrc_rsq03_maf001_extracted.raw")
hrc_names <- colnames(hrc)[7: dim(hrc)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
colnames(hrc)[7:dim(hrc)[2]] <- hrc_names[,1]

fid_iid <- hrc$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
hrc$FID <- as.integer(fid_iid[,1])
hrc$IID <- as.integer(fid_iid[,2])

hrc_X <- hrc %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()

result_hrc <- BRV(2 - hrc_X[,'chr11:116701354:G:A'], tg_y, tg_cov,"gaussian")
result_hrc
# Out:
# $zstat
# [1] -27.1247
#
# $pval
# [1] 1.17443e-161

# %%
topmed <- read.csv("APOC3_topmed_v3_rsq03_maf001_extracted.raw")
topmed_names <- colnames(topmed)[7: dim(topmed)[2]] %>% stringr::str_split(pattern = "_", simplify = TRUE)
colnames(topmed)[7:dim(topmed)[2]] <- topmed_names[,1]

fid_iid <- topmed$IID %>% stringr::str_split(pattern = "_", simplify = TRUE)
topmed$FID <- as.integer(fid_iid[,1])
topmed$IID <- as.integer(fid_iid[,2])

topmed_X <- topmed %>% arrange(FID, IID) %>% filter(FID %in% tg_id) %>% select(-c(1:6)) %>% as.matrix()

result_topmed <- BRV(2 - topmed_X[,'chr11:116830638:G:A'], tg_y, tg_cov,"gaussian")
result_topmed
# Out:
# $zstat
# [1] -28.24471
#
# $pval
# [1] 4.4723e-175

# %%
annot_001 <- read.csv("~/project/imputation-rvtest/analysis/imputation_aggregated_analysis/hrc_topmed/hrc_topmed_v3_168206ids_chr11_rsq03_maf001_annot.csv.gz") %>%
    filter(Gene.refGene == "APOC3")

# %%
annot_001
# Out:
#    Chr Start     End       Ref Alt Func.refGene    Gene.refGene
# 1  11  116830637 116830637 C   T   exonic;splicing APOC3
# 2  11  116830638 116830638 G   A   splicing        APOC3
# 3  11  116830844 116830844 G   A   exonic          APOC3
# 4  11  116830568 116830568 A   G   splicing        APOC3
# 5  11  116830592 116830592 C   T   exonic          APOC3
# 6  11  116830593 116830593 G   A   exonic          APOC3
# 7  11  116830620 116830620 C   T   exonic          APOC3
# 8  11  116830622 116830622 C   T   exonic          APOC3
# 9  11  116830808 116830808 T   G   exonic          APOC3
# 10 11  116830823 116830823 A   G   exonic          APOC3
# 11 11  116830832 116830832 G   A   exonic          APOC3
# 12 11  116830833 116830833 C   A   exonic          APOC3
# 13 11  116830838 116830838 A   G   exonic          APOC3
# 14 11  116830897 116830897 G   T   splicing        APOC3
# 15 11  116830901 116830902 AC  A   splicing        APOC3
# 16 11  116832777 116832777 G   A   exonic          APOC3
# 17 11  116832858 116832858 A   G   exonic          APOC3
# 18 11  116832873 116832873 G   A   exonic          APOC3
#    ExonicFunc.refGene MAF_nfe_exome REVEL_score ID_hg19
# 1  stopgain           6.000e-04        NA       chr11:116701353:C:T
# 2  .                  2.300e-03        NA       chr11:116701354:G:A
# 3  nonsynonymous SNV  2.000e-04     0.653       chr11:116701560:G:A
# 4  .                  6.169e-05     0.277
# 5  nonsynonymous SNV  8.807e-06     0.380
# 6  nonsynonymous SNV  1.761e-05     0.342
# 7  nonsynonymous SNV  3.525e-05     0.062
# 8  nonsynonymous SNV  0.000e+00     0.189
# 9  nonsynonymous SNV         NA     0.157
# 10 nonsynonymous SNV  8.860e-06     0.260
# 11 nonsynonymous SNV  8.866e-06     0.508
# 12 nonsynonymous SNV  5.319e-05     0.589
# 13 nonsynonymous SNV         NA     0.433
# 14 .                  1.799e-05        NA
# 15 .                  4.539e-05        NA
# 16 nonsynonymous SNV  8.823e-06     0.152
# 17 nonsynonymous SNV  1.759e-05     0.212
# 18 nonsynonymous SNV  8.800e-06     0.165
#    ID                   Function R2_hrc   R2_topmed R2       source RawScore
# 1  chr11:116830637:C:T  LoF      0.542862 0.458809  0.542862 hrc     5.613917
# 2  chr11:116830638:G:A  splicing 0.836202 0.853641  0.853641 topmed  4.947405
# 3  chr11:116830844:G:A  missense 0.973659 0.963205  0.973659 hrc     2.818346
# 4  chr11:116830568:A:G  splicing 0.000000 0.383569  0.383569 topmed  4.960331
# 5  chr11:116830592:C:T  missense 0.000000 0.591272  0.591272 topmed  2.265048
# 6  chr11:116830593:G:A  missense 0.000000 0.881843  0.881843 topmed  2.287065
# 7  chr11:116830620:C:T  missense 0.000000 0.656993  0.656993 topmed  0.402428
# 8  chr11:116830622:C:T  missense 0.000000 0.597868  0.597868 topmed  2.078035
# 9  chr11:116830808:T:G  missense 0.000000 0.570624  0.570624 topmed  0.188174
# 10 chr11:116830823:A:G  missense 0.000000 0.749498  0.749498 topmed -1.343152
# 11 chr11:116830832:G:A  missense 0.000000 0.695691  0.695691 topmed  3.295387
# 12 chr11:116830833:C:A  missense 0.000000 0.758045  0.758045 topmed  2.985550
# 13 chr11:116830838:A:G  missense 0.000000 0.321759  0.321759 topmed  2.212210
# 14 chr11:116830897:G:T  splicing 0.000000 0.918159  0.918159 topmed  6.211482
# 15 chr11:116830901:AC:A splicing 0.000000 0.448906  0.448906 topmed  0.813508
# 16 chr11:116832777:G:A  missense 0.000000 0.481611  0.481611 topmed  1.570958
# 17 chr11:116832858:A:G  missense 0.000000 0.782377  0.782377 topmed -0.753573
# 18 chr11:116832873:G:A  missense 0.000000 0.462782  0.462782 topmed  0.639350
#    PHRED  ID_hg38
# 1  34.000 chr11:116830637:C:T
# 2  33.000 chr11:116830638:G:A
# 3  23.200 chr11:116830844:G:A
# 4  33.000 chr11:116830568:A:G
# 5  21.300 chr11:116830592:C:T
# 6  21.500 chr11:116830593:G:A
# 7   5.454 chr11:116830620:C:T
# 8  19.850 chr11:116830622:C:T
# 9   2.990 chr11:116830808:T:G
# 10  0.001 chr11:116830823:A:G
# 11 24.100 chr11:116830832:G:A
# 12 23.400 chr11:116830833:C:A
# 13 21.000 chr11:116830838:A:G
# 14 35.000 chr11:116830897:G:T
# 15  9.527 chr11:116830901:AC:A
# 16 16.190 chr11:116832777:G:A
# 17  0.033 chr11:116832858:A:G
# 18  7.890 chr11:116832873:G:A
